# %% [markdown]
# # Analysis of Chicago Public School Level Performance Data-Set Using SQL and Python
#
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# -   Understand the dataset for Chicago Public School level performance
# -   Store the dataset in MySQL database on local server
# -   Retrieve metadata about tables and columns and query data from mixed case columns
# -   Solve example problems to practice your SQL skills including using built-in database functions

# %% [markdown]
# ## Chicago Public Schools - Progress Report Cards (2011-2012)
#
# The city of Chicago released a dataset showing all school level performance data used to create School Report Cards for the 2011-2012 school year. The dataset is available from the Chicago Data Portal: [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# This dataset includes a large number of metrics. Start by familiarizing yourself with the types of metrics in the database: [https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?download=true](https://data.cityofchicago.org/api/assets/AAD41A13-BE8A-4E67-B1F5-86E711E09D5F?download=true&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# **NOTE**:
#
# Do not download the dataset directly from City of Chicago portal. Instead download a static copy which is a more database friendly version from this <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_edX/data/Chicago_Public_Schools_-_Progress_Report_Cards__2011-2012-v3.csv">link</a>.
#
# Now review some of its contents.

# %% [markdown]
# ### Store the dataset in a Table
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. To analyze the data using SQL, it first needs to be stored in the database.
#
# While it is easier to read the dataset into a Pandas dataframe and then `--persit` it into the database as we saw in the previous lab, it results in mapping to default datatypes which may not be optimal for SQL querying. For example a long textual field may map to a CLOB instead of a VARCHAR.
#
# Therefore, **it is highly recommended to manually load the table using MySQL `Table Data Import Wizard`**.
#
# ##### Now open MySQL Workbench, right click on your Schema and click on `Table Data Import Wizard`. Choose the path for the csv file and click next. Select `Create New Table`, rename table as **CHICAGO_PUBLIC_SCHOOLS** and ensure `Drop Table if exist` is marked. Click next and next to import the data from the csv file. Please pay attention to the error report and ensure the import result is error free.

# %% [markdown]
# ### Connect to the database
#
# Let us now load the ipython-sql  extension and establish a connection with the database

# %%
# %load_ext sql

# %%
# Enter the connection string for your MySQL database below

import os 

from dotenv import load_dotenv
load_dotenv() 

myuser = os.environ.get('mysql_username')      # e.g. 'root'
mypassword= os.environ.get('mysql_password')   # e.g. 'sample-password' 

connection_url = 'mysql://{user}:{password}@localhost/ibm_sql_lab'.format(user=myuser,password=mypassword)

# %sql {connection_url}

# %% [markdown]
# ### Query the database system catalog to retrieve table metadata
#
# ##### You can verify that the table creation was successful by retrieving the list of all tables in your schema and checking whether the CHICAGO_PUBLIC_SCHOOLS table was created

# %%
# %%sql
#
# show full tables;
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 7 rows affected.
# [('chicago_census_data', 'BASE TABLE'),
#  ('chicago_crime_data', 'BASE TABLE'),
#  ('chicago_public_schools', 'BASE TABLE'),
#  ('chicago_socioeconomic_data', 'BASE TABLE'),
#  ('instructor', 'BASE TABLE'),
#  ('international_student_test_scores', 'BASE TABLE'),
#  ('petsale', 'BASE TABLE')]

# %% [markdown]
# ### Query the database system catalog to retrieve column metadata
#
# ##### The SCHOOLS table contains a large number of columns. How many columns does this table have?

# %%
# %%sql
#
# select count(*) as 'TOTAL_NUMBER_OF_COLUMNS'
#     from INFORMATION_SCHEMA.COLUMNS
#     where table_name = 'CHICAGO_PUBLIC_SCHOOLS';
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 1 rows affected.
# [(78,)]

# %% [markdown]
# Now retrieve the the list of columns in CHICAGO_PUBLIC_SCHOOLS table and their column type (datatype) and length.

# %%
# %%sql
#
# select COLUMN_NAME, DATA_TYPE
#     from INFORMATION_SCHEMA.COLUMNS
#     where TABLE_NAME = 'CHICAGO_PUBLIC_SCHOOLS';
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 78 rows affected.
# [('10th_Grade_PLAN_2009_', 'varchar'),
#  ('10th_Grade_PLAN_2010_', 'varchar'),
#  ('11th_Grade_Average_ACT_2011_', 'varchar'),
#  ('9th_Grade_EXPLORE_2009_', 'varchar'),
#  ('9th_Grade_EXPLORE_2010_', 'varchar'),
#  ('Adequate_Yearly_Progress_Made?_', 'varchar'),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'decimal'),
#  ('Average_Teacher_Attendance', 'decimal'),
#  ('City', 'varchar'),
#  ('Collaborative_Name', 'varchar'),
#  ('College_Eligibility_%', 'varchar'),
#  ('COLLEGE_ENROLLMENT', 'int'),
#  ('College_Enrollment_Rate_%', 'varchar'),
#  ('COMMUNITY_AREA_NAME', 'varchar'),
#  ('COMMUNITY_AREA_NUMBER', 'int'),
#  ('CPS_Performance_Policy_Level', 'varchar'),
#  ('CPS_Performance_Policy_Status', 'varchar'),
#  ('Elementary,_Middle,_or_High_School', 'varchar'),
#  ('Environment_Icon_', 'varchar'),
#  ('Environment_Score', 'int'),
#  ('Family_Involvement_Icon', 'varchar'),
#  ('Family_Involvement_Score', 'varchar'),
#  ('Freshman_on_Track_Rate_%', 'varchar'),
#  ('General_Services_Route_', 'int'),
#  ('Gr-8_Explore_Math_%', 'varchar'),
#  ('Gr-8_Explore_Read_%', 'varchar'),
#  ('Gr3-5_Grade_Level_Math_%', 'varchar'),
#  ('Gr3-5_Grade_Level_Read_%_', 'varchar'),
#  ('Gr3-5_Keep_Pace_Math_%', 'varchar'),
#  ('Gr3-5_Keep_Pace_Read_%', 'varchar'),
#  ('Gr6-8_Grade_Level_Math_%', 'varchar'),
#  ('Gr6-8_Grade_Level_Read_%', 'varchar'),
#  ('Gr6-8_Keep_Pace_Math%', 'varchar'),
#  ('Gr6-8_Keep_Pace_Read_%', 'varchar'),
#  ('Graduation_Rate_%', 'varchar'),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'tinyint'),
#  ('Individualized_Education_Program_Compliance_Rate_', 'decimal'),
#  ('Instruction_Icon_', 'varchar'),
#  ('Instruction_Score', 'int'),
#  ('ISAT_Exceeding_Math_%', 'decimal'),
#  ('ISAT_Exceeding_Reading_%_', 'decimal'),
#  ('ISAT_Value_Add_Color_Math', 'varchar'),
#  ('ISAT_Value_Add_Color_Read', 'varchar'),
#  ('ISAT_Value_Add_Math', 'decimal'),
#  ('ISAT_Value_Add_Read', 'decimal'),
#  ('Latitude', 'decimal'),
#  ('Leaders_Icon_', 'varchar'),
#  ('Leaders_Score_', 'varchar'),
#  ('Link_', 'varchar'),
#  ('Location', 'varchar'),
#  ('Longitude', 'decimal'),
#  ('NAME_OF_SCHOOL', 'varchar'),
#  ('Net_Change_EXPLORE_and_PLAN', 'varchar'),
#  ('Net_Change_PLAN_and_ACT', 'varchar'),
#  ('Network_Manager', 'varchar'),
#  ('Parent_Engagement_Icon_', 'varchar'),
#  ('Parent_Engagement_Score', 'varchar'),
#  ('Parent_Environment_Icon', 'varchar'),
#  ('Parent_Environment_Score', 'varchar'),
#  ('Phone_Number', 'varchar'),
#  ('Pk-2_Literacy_%', 'varchar'),
#  ('Pk-2_Math_%', 'varchar'),
#  ('Police_District', 'int'),
#  ('Rate_of_Misconducts_per_100_students_', 'decimal'),
#  ('Safety_Icon_', 'varchar'),
#  ('SAFETY_SCORE', 'int'),
#  ('School_ID', 'int'),
#  ('State', 'varchar'),
#  ('Street_Address', 'varchar'),
#  ('Students_Passing__Algebra_%', 'varchar'),
#  ('Students_Taking__Algebra_%', 'varchar'),
#  ('Teachers_Icon_', 'varchar'),
#  ('Teachers_Score', 'varchar'),
#  ('Track_Schedule', 'varchar'),
#  ('Ward', 'int'),
#  ('X_COORDINATE', 'decimal'),
#  ('Y_COORDINATE', 'decimal'),
#  ('ZIP_Code', 'int')]

# %% [markdown]
# ### Questions
#
# 1.  Is the column name for the "SCHOOL ID" attribute in upper or mixed case?
# 2.  What is the name of "Community Area Name" column in your table? Does it have spaces?
# 3.  Are there any columns in whose names the spaces and paranthesis (round brackets) have been replaced by the underscore character "\_"?

# %% [markdown]
# ## Problems
#
# ### Problem 1
#
# ##### How many Elementary Schools are in the dataset?

# %%
# %%sql
#
# select count(*) as 'NUMBER_OF_ELEMENTARY_SCHOOLS'
#     from CHICAGO_PUBLIC_SCHOOLS
#     where `Elementary,_Middle,_or_High_School` = 'ES';
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 1 rows affected.
# [(462,)]

# %% [markdown]
# ### Problem 2
#
# ##### What is the highest Safety Score?

# %%
# %%sql
#
# select max(SAFETY_SCORE) as 'HIGHEST_SAFETY_SCORE'
#     from CHICAGO_PUBLIC_SCHOOLS;
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 1 rows affected.
# [(99,)]

# %% [markdown]
# ### Problem 3
#
# ##### Which schools have highest Safety Score?

# %%
# %%sql
#
# select NAME_OF_SCHOOL, SAFETY_SCORE
#     from CHICAGO_PUBLIC_SCHOOLS
#     where SAFETY_SCORE = (select max(SAFETY_SCORE)
#                           from CHICAGO_PUBLIC_SCHOOLS);
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 19 rows affected.
# [('Northside Learning Center High School', 99),
#  ('Northside College Preparatory High School', 99),
#  ('Alexander Graham Bell Elementary School', 99),
#  ('James G Blaine Elementary School', 99),
#  ('Augustus H Burley Elementary School', 99),
#  ('Stephen Decatur Classical Elementary School', 99),
#  ('Edgebrook Elementary School', 99),
#  ('LaSalle Elementary Language Academy', 99),
#  ('Abraham Lincoln Elementary School', 99),
#  ('James E McDade Elementary Classical School', 99),
#  ('Ellen Mitchell Elementary School', 99),
#  ('Annie Keller Elementary Gifted Magnet School', 99),
#  ('Norwood Park Elementary School', 99),
#  ('Oriole Park Elementary School', 99),
#  ('Edgar Allan Poe Elementary Classical School', 99),
#  ('Sauganash Elementary School', 99),
#  ('Wildwood Elementary School', 99),
#  ('Talman Elementary School', 99),
#  ('Mary E Courtenay Elementary Language Arts Center', 99)]

# %% [markdown]
# ### Problem 4
#
# ##### What are the top 10 schools with the highest "Average Student Attendance"?

# %%
# %%sql
#
# select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE
#     from CHICAGO_PUBLIC_SCHOOLS
#     order by AVERAGE_STUDENT_ATTENDANCE desc
#     limit 10;
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 10 rows affected.
# [('Rachel Carson Elementary School', Decimal('0.98')),
#  ('Annie Keller Elementary Gifted Magnet School', Decimal('0.98')),
#  ('Orozco Fine Arts & Sciences Elementary School', Decimal('0.98')),
#  ('Edgar Allan Poe Elementary Classical School', Decimal('0.98')),
#  ('James Ward Elementary School', Decimal('0.98')),
#  ('John Charles Haines Elementary School', Decimal('0.98')),
#  ('Frank W Gunsaulus Elementary Scholastic Academy', Decimal('0.97')),
#  ('Frederic Chopin Elementary School', Decimal('0.97')),
#  ('Eugene Field Elementary School', Decimal('0.97')),
#  ('Louisa May Alcott Elementary School', Decimal('0.97'))]

# %% [markdown]
# ### Problem 5
#
# ##### Retrieve the list of 5 Schools with the lowest Average Student Attendance sorted in ascending order based on attendance

# %%
# %%sql
#
# select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE
#     from CHICAGO_PUBLIC_SCHOOLS
#     order by AVERAGE_STUDENT_ATTENDANCE
#     limit 5;
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 5 rows affected.
# [('Velma F Thomas Early Childhood Center', None),
#  ('Richard T Crane Technical Preparatory High School', Decimal('0.58')),
#  ('Barbara Vick Early Childhood & Family Center', Decimal('0.61')),
#  ('Dyett High School', Decimal('0.63')),
#  ('Wendell Phillips Academy High School', Decimal('0.63'))]

# %% [markdown]
# ### Problem 6
#
# ##### Now remove the '%' sign from the above result set for Average Student Attendance column

# %%
# %%sql
#
# select NAME_OF_SCHOOL, replace(AVERAGE_STUDENT_ATTENDANCE, '%', '') as AVERAGE_STUDENT_ATTENDANCE
#     from CHICAGO_PUBLIC_SCHOOLS
#     order by AVERAGE_STUDENT_ATTENDANCE
#     limit 5;
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 5 rows affected.
# [('Velma F Thomas Early Childhood Center', None),
#  ('Richard T Crane Technical Preparatory High School', '0.58'),
#  ('Barbara Vick Early Childhood & Family Center', '0.61'),
#  ('Dyett High School', '0.63'),
#  ('Wendell Phillips Academy High School', '0.63')]

# %% [markdown]
# ### Problem 7
#
# ##### Which Schools have Average Student Attendance lower than 70%?

# %%
# %%sql
#
# select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE
#     from CHICAGO_PUBLIC_SCHOOLS
#     where AVERAGE_STUDENT_ATTENDANCE < 70
#     order by AVERAGE_STUDENT_ATTENDANCE desc
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 565 rows affected.
# [('Rachel Carson Elementary School', Decimal('0.98')),
#  ('John Charles Haines Elementary School', Decimal('0.98')),
#  ('Annie Keller Elementary Gifted Magnet School', Decimal('0.98')),
#  ('Edgar Allan Poe Elementary Classical School', Decimal('0.98')),
#  ('James Ward Elementary School', Decimal('0.98')),
#  ('Orozco Fine Arts & Sciences Elementary School', Decimal('0.98')),
#  ('Louisa May Alcott Elementary School', Decimal('0.97')),
#  ('Thomas A Edison Regional Gifted Center Elementary School', Decimal('0.97')),
#  ('Augustus H Burley Elementary School', Decimal('0.97')),
#  ('Little Village Elementary School', Decimal('0.97')),
#  ('Frederic Chopin Elementary School', Decimal('0.97')),
#  ('Edgebrook Elementary School', Decimal('0.97')),
#  ('Eugene Field Elementary School', Decimal('0.97')),
#  ('Frank W Gunsaulus Elementary Scholastic Academy', Decimal('0.97')),
#  ('Emiliano Zapata Elementary Academy', Decimal('0.97')),
#  ('Hawthorne Elementary Scholastic Academy', Decimal('0.97')),
#  ('Robert Healy Elementary School', Decimal('0.97')),
#  ('William G Hibbard Elementary School', Decimal('0.97')),
#  ('Maria Saucedo Elementary Scholastic Academy', Decimal('0.97')),
#  ('LaSalle Elementary Language Academy', Decimal('0.97')),
#  ('Andrew Jackson Elementary Language Academy', Decimal('0.97')),
#  ('James B McPherson Elementary School', Decimal('0.97')),
#  ('Mark Sheridan Elementary Math & Science Academy', Decimal('0.97')),
#  ('Oriole Park Elementary School', Decimal('0.97')),
#  ('William Bishop Owen Scholastic Academy Elementary School', Decimal('0.97')),
#  ('Helen Peirce International Studies Elementary School', Decimal('0.97')),
#  ('Ambrose Plamondon Elementary School', Decimal('0.97')),
#  ('Frank W Reilly Elementary School', Decimal('0.97')),
#  ('Sidney Sawyer Elementary School', Decimal('0.97')),
#  ('James Shields Elementary School', Decimal('0.97')),
#  ('Mark Skinner Elementary School', Decimal('0.97')),
#  ('John H Vanderpoel Elementary Magnet School', Decimal('0.97')),
#  ('Albany Park Multicultural Academy', Decimal('0.97')),
#  ('Joseph Brennemann Elementary School', Decimal('0.97')),
#  ('Lenart Elementary Regional Gifted Center', Decimal('0.97')),
#  ('Calmeca Academy of Fine Arts and Dual Language', Decimal('0.97')),
#  ('DeVry University Advantage Academy High School', Decimal('0.97')),
#  ('Suder Montessori Magnet Elementary School', Decimal('0.97')),
#  ('Frazier Prospective IB Magnet Elementary School', Decimal('0.97')),
#  ('Disney II Magnet School', Decimal('0.97')),
#  ('Federico Garcia Lorca Elementary School', Decimal('0.97')),
#  ('Albert G Lane Technical High School', Decimal('0.96')),
#  ('Northside College Preparatory High School', Decimal('0.96')),
#  ('Jane Addams Elementary School', Decimal('0.96')),
#  ('George Armstrong International Studies Elementary School', Decimal('0.96')),
#  ('John J Audubon Elementary School', Decimal('0.96')),
#  ('Alice L Barnard Computer Math & Science Center Elementary School', Decimal('0.96')),
#  ('Newton Bateman Elementary School', Decimal('0.96')),
#  ('Jean Baptiste Beaubien Elementary School', Decimal('0.96')),
#  ('Alexander Graham Bell Elementary School', Decimal('0.96')),
#  ('James G Blaine Elementary School', Decimal('0.96')),
#  ('Daniel Boone Elementary School', Decimal('0.96')),
#  ('Norman A Bridge Elementary School', Decimal('0.96')),
#  ('Burnham Elementary Inclusive Academy', Decimal('0.96')),
#  ('Rosario Castellanos Elementary School', Decimal('0.96')),
#  ('Jonathan Burr Elementary School', Decimal('0.96')),
#  ('John C Burroughs Elementary School', Decimal('0.96')),
#  ('Arthur E Canty Elementary School', Decimal('0.96')),
#  ('Horace Greeley Elementary School', Decimal('0.96')),
#  ('Christopher Columbus Elementary School', Decimal('0.96')),
#  ('Jordan Elementary Community School', Decimal('0.96')),
#  ('John C Coonley Elementary School', Decimal('0.96')),
#  ('Peter Cooper Elementary Dual Language Academy', Decimal('0.96')),
#  ('Manuel Perez Elementary School', Decimal('0.96')),
#  ('Everett McKinley Dirksen Elementary School', Decimal('0.96')),
#  ('Charles R Darwin Elementary School', Decimal('0.96')),
#  ('Charles Gates Dawes Elementary School', Decimal('0.96')),
#  ('Stephen Decatur Classical Elementary School', Decimal('0.96')),
#  ('William E Dever Elementary School', Decimal('0.96')),
#  ('John C Dore Elementary School', Decimal('0.96')),
#  ('Turner-Drew Elementary Language Academy', Decimal('0.96')),
#  ('Christian Ebinger Elementary School', Decimal('0.96')),
#  ('Laughlin Falconer Elementary School', Decimal('0.96')),
#  ('Gerald Delgado Kanoon Elementary Magnet School', Decimal('0.96')),
#  ('Franklin Elementary Fine Arts Center', Decimal('0.96')),
#  ('Joseph E Gary Elementary School', Decimal('0.96')),
#  ('Johann W von Goethe Elementary School', Decimal('0.96')),
#  ('Virgil Grissom Elementary School', Decimal('0.96')),
#  ('William C Goudy Elementary School', Decimal('0.96')),
#  ('William P Gray Elementary School', Decimal('0.96')),
#  ('Josefa Ortiz De Dominguez Elementary School', Decimal('0.96')),
#  ('Ariel Elementary Community Academy', Decimal('0.96')),
#  ('Nathanael Greene Elementary School', Decimal('0.96')),
#  ('Walter Q Gresham Elementary School', Decimal('0.96')),
#  ('Helge A Haugan Elementary School', Decimal('0.96')),
#  ('Stephen K Hayt Elementary School', Decimal('0.96')),
#  ('Agustin Lara Elementary Academy', Decimal('0.96')),
#  ('Julia Ward Howe Elementary School of Excellence', Decimal('0.96')),
#  ('Minnie Mars Jamieson Elementary School', Decimal('0.96')),
#  ('Pilsen Elementary Community Academy', Decimal('0.96')),
#  ('Joseph Jungman Elementary School', Decimal('0.96')),
#  ('Kate S Kellogg Elementary School', Decimal('0.96')),
#  ('Joyce Kilmer Elementary School', Decimal('0.96')),
#  ('Lazaro Cardenas Elementary School', Decimal('0.96')),
#  ('Abraham Lincoln Elementary School', Decimal('0.96')),
#  ('Carl von Linne Elementary School', Decimal('0.96')),
#  ('Henry D Lloyd Elementary School', Decimal('0.96')),
#  ('Josephine C Locke Elementary School', Decimal('0.96')),
#  ('Mary Lyon Elementary School', Decimal('0.96')),
#  ('John L Marsh Elementary School', Decimal('0.96')),
#  ('Cyrus H McCormick Elementary School', Decimal('0.96')),
#  ('James E McDade Elementary Classical School', Decimal('0.96')),
#  ('Ellen Mitchell Elementary School', Decimal('0.96')),
#  ('Inter-American Elementary Magnet School', Decimal('0.96')),
#  ('Mount Greenwood Elementary School', Decimal('0.96')),
#  ('John B Murphy Elementary School', Decimal('0.96')),
#  ('Phillip Murray Elementary Language Academy', Decimal('0.96')),
#  ('Louis Nettelhorst Elementary School', Decimal('0.96')),
#  ('Florence Nightingale Elementary School', Decimal('0.96')),
#  ('William P Nixon Elementary School', Decimal('0.96')),
#  ('Norwood Park Elementary School', Decimal('0.96')),
#  ('William J Onahan Elementary School', Decimal('0.96')),
#  ('James Otis Elementary School', Decimal('0.96')),
#  ('John Palmer Elementary School', Decimal('0.96')),
#  ('Ferdinand Peck Elementary School', Decimal('0.96')),
#  ('Washington Irving Elementary School', Decimal('0.96')),
#  ('Harold Washington Elementary School', Decimal('0.96')),
#  ('Irma C Ruiz Elementary School', Decimal('0.96')),
#  ('John J Pershing Elementary Humanities Magnet', Decimal('0.96')),
#  ('Mary Gage Peterson Elementary School', Decimal('0.96')),
#  ('Josiah Pickard Elementary School', Decimal('0.96')),
#  ('Pulaski International Academy Elmentary School', Decimal('0.96')),
#  ('Peter A Reinberg Elementary School', Decimal('0.96')),
#  ('Philip Rogers Elementary School', Decimal('0.96')),
#  ('Martin A Ryerson Elementary School', Decimal('0.96')),
#  ('Sauganash Elementary School', Decimal('0.96')),
#  ('Harriet E Sayre Elementary Language Academy', Decimal('0.96')),
#  ('Jonathan Y Scammon Elementary School', Decimal('0.96')),
#  ('Franz Peter Schubert Elementary School', Decimal('0.96')),
#  ('William H Seward Communication Arts Academy Elementary School', Decimal('0.96')),
#  ('Washington D Smyser Elementary School', Decimal('0.96')),
#  ('Hannah G Solomon Elementary School', Decimal('0.96')),
#  ('John Spry Elementary Community School', Decimal('0.96')),
#  ('Adlai E Stevenson Elementary School', Decimal('0.96')),
#  ('Stone Elementary Scholastic Academy', Decimal('0.96')),
#  ('Elizabeth H Sutherland Elementary School', Decimal('0.96')),
#  ('George B Swift Elementary Specialty School', Decimal('0.96')),
#  ('Mancel Talcott Elementary School', Decimal('0.96')),
#  ('Johnnie Colemon Elementary Academy', Decimal('0.96')),
#  ('Ole A Thorp Elementary Scholastic Academy', Decimal('0.96')),
#  ('Enrico Tonti Elementary School', Decimal('0.96')),
#  ('Mark Twain Elementary School', Decimal('0.96')),
#  ('Alessandro Volta Elementary School', Decimal('0.96')),
#  ('George Washington Elementary School', Decimal('0.96')),
#  ('Thomas J Waters Elementary School', Decimal('0.96')),
#  ('Socorro Sandoval Elementary School', Decimal('0.96')),
#  ('Eli Whitney Elementary School', Decimal('0.96')),
#  ('Wildwood Elementary School', Decimal('0.96')),
#  ('John Calhoun North Elementary School', Decimal('0.96')),
#  ('Chicago Academy Elementary School', Decimal('0.96')),
#  ('Talman Elementary School', Decimal('0.96')),
#  ('Adam Clayton Powell Paideia Community Academy Elementary School', Decimal('0.96')),
#  ('New Field Elementary School', Decimal('0.96')),
#  ('Ashburn Community Elementary School', Decimal('0.96')),
#  ('Benjamin E Mays Elementary Academy', Decimal('0.96')),
#  ('Mary E McDowell Elementary School', Decimal('0.96')),
#  ('Amelia Earhart Options for Knowledge Elementary School', Decimal('0.96')),
#  ('Brighton Park Elementary School', Decimal('0.96')),
#  ('Evergreen Academy Middle School', Decimal('0.96')),
#  ('Robert A Black Magnet Elementary School', Decimal('0.96')),
#  ('North River Elementary School', Decimal('0.96')),
#  ('Spry Community Links High School', Decimal('0.96')),
#  ('Walt Disney Magnet Elementary School', Decimal('0.96')),
#  ('Pershing West Middle School', Decimal('0.96')),
#  ('Tarkington School of Excellence Elementary School', Decimal('0.96')),
#  ('Edison Park Elementary School', Decimal('0.96')),
#  ('Irene C. Hernandez Middle School for the Advancement of Science', Decimal('0.96')),
#  ('Skinner North', Decimal('0.96')),
#  ('Mariano Azuela Elementary School', Decimal('0.96')),
#  ('Whitney M Young Magnet High School', Decimal('0.95')),
#  ('Louis A Agassiz Elementary School', Decimal('0.95')),
#  ('Crispus Attucks Elementary School', Decimal('0.95')),
#  ('John Barry Elementary School', Decimal('0.95')),
#  ('Jacob Beidler Elementary School', Decimal('0.95')),
#  ('Hiram H Belding Elementary School', Decimal('0.95')),
#  ('Scott Joplin Elementary School', Decimal('0.95')),
#  ('Lionel Hampton Fine & Performing Arts Elementary School', Decimal('0.95')),
#  ('Alex Haley Elementary Academy', Decimal('0.95')),
#  ('Lorenz Brentano Math & Science Academy Elementary School', Decimal('0.95')),
#  ('Lyman A Budlong Elementary School', Decimal('0.95')),
#  ('Luther Burbank Elementary School', Decimal('0.95')),
#  ('Burnside Elementary Scholastic Academy', Decimal('0.95')),
#  ('Michael M Byrne Elementary School', Decimal('0.95')),
#  ('Andrew Carnegie Elementary School', Decimal('0.95')),
#  ('Carroll-Rosenwald Specialty Elementary School', Decimal('0.95')),
#  ('Eliza Chappell Elementary School', Decimal('0.95')),
#  ('Salmon P Chase Elementary School', Decimal('0.95')),
#  ('Henry Clay Elementary School', Decimal('0.95')),
#  ('Grover Cleveland Elementary School', Decimal('0.95')),
#  ('DeWitt Clinton Elementary School', Decimal('0.95')),
#  ('Henry R Clissold Elementary School', Decimal('0.95')),
#  ('Edward Coles Elementary Language Academy', Decimal('0.95')),
#  ('Daniel J Corkery Elementary School', Decimal('0.95')),
#  ('Nathan S Davis Elementary School', Decimal('0.95')),
#  ('Arthur Dixon Elementary School', Decimal('0.95')),
#  ('Thomas Drummond Elementary School', Decimal('0.95')),
#  ('John F Eberhart Elementary School', Decimal('0.95')),
#  ('Ralph H Metcalfe Elementary Community Academy', Decimal('0.95')),
#  ('Richard Edwards Elementary School', Decimal('0.95')),
#  ('Leif Ericson Elementary Scholastic Academy', Decimal('0.95')),
#  ('Edward Everett Elementary School', Decimal('0.95')),
#  ('Telpochcalli Elementary School', Decimal('0.95')),
#  ('Belmont-Cragin Elementary School', Decimal('0.95')),
#  ('Joseph Kellman Corporate Community Elementary School', Decimal('0.95')),
#  ('Robert Fulton Elementary School', Decimal('0.95')),
#  ('Frederick Funston Elementary School', Decimal('0.95')),
#  ('Matthew Gallistel Elementary Language Academy', Decimal('0.95')),
#  ('John W Garvy Elementary School', Decimal('0.95')),
#  ('John Milton Gregory Elementary School', Decimal('0.95')),
#  ('Robert L Grimes Elementary School', Decimal('0.95')),
#  ('Nathan Hale Elementary School', Decimal('0.95')),
#  ('Alexander Hamilton Elementary School', Decimal('0.95')),
#  ('Charles G Hammond Elementary School', Decimal('0.95')),
#  ('William F Finkl Elementary School', Decimal('0.95')),
#  ('James Hedges Elementary School', Decimal('0.95')),
#  ('Patrick Henry Elementary School', Decimal('0.95')),
#  ('South Loop Elementary School', Decimal('0.95')),
#  ('Rufus M Hitch Elementary School', Decimal('0.95')),
#  ('Charles N Holden Elementary School', Decimal('0.95')),
#  ('Thomas Hoyne Elementary School', Decimal('0.95')),
#  ('Edward N Hurley Elementary School', Decimal('0.95')),
#  ('Galileo Math & Science Scholastic Academy Elementary School', Decimal('0.95')),
#  ('Friedrich Ludwig Jahn Elementary School', Decimal('0.95')),
#  ('Joshua D Kershaw Elementary School', Decimal('0.95')),
#  ('John H Kinzie Elementary School', Decimal('0.95')),
#  ('Rudyard Kipling Elementary School', Decimal('0.95')),
#  ('Rodolfo Lozano Bilingual & International Center Elementary School', Decimal('0.95')),
#  ('Joseph Lovett Elementary School', Decimal('0.95')),
#  ('James Madison Elementary School', Decimal('0.95')),
#  ('Oscar F Mayer Elementary School', Decimal('0.95')),
#  ('William J & Charles H Mayo Elementary School', Decimal('0.95')),
#  ('Hanson Park Elementary School', Decimal('0.95')),
#  ('James Monroe Elementary School', Decimal('0.95')),
#  ('Wolfgang A Mozart Elementary School', Decimal('0.95')),
#  ('Henry H Nash Elementary School', Decimal('0.95')),
#  ('Walter L Newberry Math & Science Academy Elementary School', Decimal('0.95')),
#  ('Alfred Nobel Elementary School', Decimal('0.95')),
#  ('William B Ogden Elementary School', Decimal('0.95')),
#  ('Park Manor Elementary School', Decimal('0.95')),
#  ('Louis Pasteur Elementary School', Decimal('0.95')),
#  ('Elizabeth Peabody Elementary School', Decimal('0.95')),
#  ('Ernst Prussing Elementary School', Decimal('0.95')),
#  ('Ravenswood Elementary School', Decimal('0.95')),
#  ('William H Ray Elementary School', Decimal('0.95')),
#  ('Cesar E Chavez Multicultural Academic Center Elementary School', Decimal('0.95')),
#  ('Columbia Explorers Elementary Academy', Decimal('0.95')),
#  ('Beulah Shoesmith Elementary School', Decimal('0.95')),
#  ('Graeme Stewart Elementary School', Decimal('0.95')),
#  ('Dunne Technology Academy', Decimal('0.95')),
#  ('Joseph Stockton Elementary School', Decimal('0.95')),
#  ('Douglas Taylor Elementary School', Decimal('0.95')),
#  ('Francisco I Madero Middle School', Decimal('0.95')),
#  ('John A Walsh Elementary School', Decimal('0.95')),
#  ('Joseph Warren Elementary School', Decimal('0.95')),
#  ('Daniel Webster Elementary School', Decimal('0.95')),
#  ('John Greenleaf Whittier Elementary School', Decimal('0.95')),
#  ('A.N. Pritzker School', Decimal('0.95')),
#  ('National Teachers Elementary Academy', Decimal('0.95')),
#  ('Richard J Daley Elementary Academy', Decimal('0.95')),
#  ('Edward Beasley Elementary Magnet Academic Center', Decimal('0.95')),
#  ('Rueben Salazar Elementary Bilingual Center', Decimal('0.95')),
#  ('Willa Cather Elementary School', Decimal('0.95')),
#  ('James Weldon Johnson Elementary School', Decimal('0.95')),
#  ('Richard Henry Lee Elementary School', Decimal('0.95')),
#  ('Thomas J Higgins Elementary Community Academy', Decimal('0.95')),
#  ('Jose De Diego Elementary Community Academy', Decimal('0.95')),
#  ('Ana Roque de Duprey Elementary School', Decimal('0.95')),
#  ('Logandale Middle School', Decimal('0.95')),
#  ('Albert R Sabin Elementary Magnet School', Decimal('0.95')),
#  ('Durkin Park Elementary School', Decimal('0.95')),
#  ('Mary E Courtenay Elementary Language Arts Center', Decimal('0.95')),
#  ('Medgar Evers Elementary School', Decimal('0.95')),
#  ('LaSalle II Magnet Elementary School', Decimal('0.95')),
#  ('Dr Jorge Prieto Math and Science', Decimal('0.95')),
#  ('Marvin Camras Elementary School', Decimal('0.95')),
#  ('West Ridge Elementary School', Decimal('0.95')),
#  ('William Jones College Preparatory High School', Decimal('0.94')),
#  ('George Westinghouse High School', Decimal('0.94')),
#  ('Phillip D Armour Elementary School', Decimal('0.94')),
#  ('Ames Middle School', Decimal('0.94')),
#  ('George Rogers Clark Elementary School', Decimal('0.94')),
#  ('George F Cassell Elementary School', Decimal('0.94')),
#  ('Thomas Chalmers Specialty Elementary School', Decimal('0.94')),
#  ('John W Cook Elementary School', Decimal('0.94')),
#  ('Charles S Deneen Elementary School', Decimal('0.94')),
#  ('Mary Mapes Dodge Elementary Renaissance Academy', Decimal('0.94')),
#  ('John B Drake Elementary School', Decimal('0.94')),
#  ('Charles W Earle Elementary School', Decimal('0.94')),
#  ('George W Curtis Elementary School', Decimal('0.94')),
#  ('James B Farnsworth Elementary School', Decimal('0.94')),
#  ('Foster Park Elementary School', Decimal('0.94')),
#  ('Samuel Gompers Fine Arts Options Elementary School', Decimal('0.94')),
#  ('Ninos Heroes Elementary Academic Center', Decimal('0.94')),
#  ('John H Hamline Elementary School', Decimal('0.94')),
#  ('Sharon Christa McAuliffe Elementary School', Decimal('0.94')),
#  ('Bret Harte Elementary School', Decimal('0.94')),
#  ('Woodlawn Community Elementary School', Decimal('0.94')),
#  ('Helen M Hefferan Elementary School', Decimal('0.94')),
#  ('Paul Cuffe Math-Science Technology Academy Elementary School', Decimal('0.94')),
#  ('Countee Cullen Elementary School', Decimal('0.94')),
#  ('Charles Evans Hughes Elementary School', Decimal('0.94')),
#  ('Jean D Lafayette Elementary School', Decimal('0.94')),
#  ('Wendell E Green Elementary School', Decimal('0.94')),
#  ('Francis M McKay Elementary School', Decimal('0.94')),
#  ('Ronald Brown Elementary Community Academy', Decimal('0.94')),
#  ('West Park Elementary Academy', Decimal('0.94')),
#  ('Richard J Oglesby Elementary School', Decimal('0.94')),
#  ('Marcus Moziah Garvey Elementary School', Decimal('0.94')),
#  ('John T Pirie Fine Arts & Academic Center Elementary School', Decimal('0.94')),
#  ('Portage Park Elementary School', Decimal('0.94')),
#  ('William H Prescott Elementary School', Decimal('0.94')),
#  ('George M Pullman Elementary School', Decimal('0.94')),
#  ('William C Reavis Math & Science Specialty Elementary School', Decimal('0.94')),
#  ('Martha Ruggles Elementary School', Decimal('0.94')),
#  ('Arna Wendell Bontemps Elementary School', Decimal('0.94')),
#  ('Harriet Beecher Stowe Elementary School', Decimal('0.94')),
#  ('Charles Sumner  Math & Science Community Acad Elementary School', Decimal('0.94')),
#  ('Lyman Trumbull Elementary School', Decimal('0.94')),
#  ('Richard Yates Elementary School', Decimal('0.94')),
#  ('Ella Flagg Young Elementary School', Decimal('0.94')),
#  ('Ludwig Van Beethoven Elementary School', Decimal('0.94')),
#  ('Robert Nathaniel Dett Elementary School', Decimal('0.94')),
#  ('Dvorak Technology Academy', Decimal('0.94')),
#  ('Morton School of Excellence', Decimal('0.94')),
#  ('John Foster Dulles Elementary School', Decimal('0.94')),
#  ('John T McCutcheon Elementary School', Decimal('0.94')),
#  ('Edward White Elementary Career Academy', Decimal('0.94')),
#  ('Thurgood Marshall Middle School', Decimal('0.94')),
#  ('Ogden International High School', Decimal('0.94')),
#  ('South Shore Fine Arts Academy', Decimal('0.94')),
#  ('Walter Payton College Preparatory High School', Decimal('0.93')),
#  ('Dr  Martin Luther King  Jr  College Prep High School', Decimal('0.93')),
#  ('Chicago High School for Agricultural Sciences', Decimal('0.93')),
#  ('Nicholson Technology Academy', Decimal('0.93')),
#  ('Frank I Bennett Elementary School', Decimal('0.93')),
#  ('William H Brown Elementary School', Decimal('0.93')),
#  ('Charles S Brownell Elementary School', Decimal('0.93')),
#  ('Edward A Bouchet Math & Science Academy Elementary School', Decimal('0.93')),
#  ('Charles P Caldwell Academy of Math & Science Elementary School', Decimal('0.93')),
#  ('Daniel R Cameron Elementary School', Decimal('0.93')),
#  ('Ira F Aldridge Elementary School', Decimal('0.93')),
#  ('Crown Community Academy of Fine Arts Center Elementary School', Decimal('0.93')),
#  ('Edward C Delano Elementary School', Decimal('0.93')),
#  ('Edward K Ellington Elementary School', Decimal('0.93')),
#  ('Esmond Elementary School', Decimal('0.93')),
#  ('Fernwood Elementary School', Decimal('0.93')),
#  ('John Fiske Elementary School', Decimal('0.93')),
#  ('Fort Dearborn Elementary School', Decimal('0.93')),
#  ('Alexander Graham Elementary School', Decimal('0.93')),
#  ('John Harvard Elementary School of Excellence', Decimal('0.93')),
#  ('John Hay Elementary Community Academy', Decimal('0.93')),
#  ('Victor Herbert Elementary School', Decimal('0.93')),
#  ('James Russell Lowell Elementary School', Decimal('0.93')),
#  ('Northwest Middle School', Decimal('0.93')),
#  ('Horace Mann Elementary School', Decimal('0.93')),
#  ('Marquette Elementary School', Decimal('0.93')),
#  ('Michael Faraday Elementary School', Decimal('0.93')),
#  ('Fairfield Elementary Academy', Decimal('0.93')),
#  ('George B McClellan Elementary School', Decimal('0.93')),
#  ('Bernhard Moos Elementary School', Decimal('0.93')),
#  ('Donald Morrill Math & Science Elementary School', Decimal('0.93')),
#  ('Mount Vernon Elementary School', Decimal('0.93')),
#  ('Ida B Wells Preparatory Elementary Academy', Decimal('0.93')),
#  ('Laura S Ward Elementary School', Decimal('0.93')),
#  ('William H Ryder Math & Science Specialty Elementary School', Decimal('0.93')),
#  ('Louis Armstrong Math & Science Elementary School', Decimal('0.93')),
#  ('Arnold Mireles Elementary Academy', Decimal('0.93')),
#  ('John D Shoop Math-Science Technical Academy Elementary School', Decimal('0.93')),
#  ('Spencer Technology Academy', Decimal('0.93')),
#  ('Alexander von Humboldt Elementary School', Decimal('0.93')),
#  ('Dumas Technology Academy', Decimal('0.93')),
#  ('Jensen Elementary Scholastic Academy', Decimal('0.93')),
#  ('Oliver S Westcott Elementary School', Decimal('0.93')),
#  ('George Leland Elementary School', Decimal('0.93')),
#  ('Williams Preparatory Academy Middle School', Decimal('0.93')),
#  ('Chicago Academy High School', Decimal('0.93')),
#  ('Claremont Academy Elementary School', Decimal('0.93')),
#  ('Nathan R Goldblatt Elementary School', Decimal('0.93')),
#  ('William E B Dubois Elementary School', Decimal('0.93')),
#  ('Mary McLeod Bethune Elementary School', Decimal('0.93')),
#  ('Charles H Wacker Elementary School', Decimal('0.93')),
#  ('Oscar DePriest Elementary School', Decimal('0.93')),
#  ('Mahalia Jackson Elementary School', Decimal('0.93')),
#  ('Hyman G Rickover Naval Academy High School', Decimal('0.93')),
#  ('Robert Lindblom Math & Science Academy High School', Decimal('0.93')),
#  ('Air Force Academy High School', Decimal('0.93')),
#  ('Sir Miles Davis Magnet Elementary Academy', Decimal('0.93')),
#  ('Alcott High School for the Humanities', Decimal('0.93')),
#  ('George Washington Carver Military Academy High School', Decimal('0.92')),
#  ('John P Altgeld Elementary School', Decimal('0.92')),
#  ('Avalon Park Elementary School', Decimal('0.92')),
#  ('Clara Barton Elementary School', Decimal('0.92')),
#  ('Perkins Bass Elementary School', Decimal('0.92')),
#  ('Myra Bradwell Communications Arts & Sciences Elementary School', Decimal('0.92')),
#  ('Orville T Bright Elementary School', Decimal('0.92')),
#  ('Anna R. Langford Community Academy', Decimal('0.92')),
#  ('Elaine O Goodlow Elementary Magnet School', Decimal('0.92')),
#  ('Melville W Fuller Elementary School', Decimal('0.92')),
#  ('Stephen F Gale Elementary Community Academy', Decimal('0.92')),
#  ('Frank L Gillespie Elementary School', Decimal('0.92')),
#  ('Asa Philip Randolph Elementary School', Decimal('0.92')),
#  ('Wendell Smith Elementary School', Decimal('0.92')),
#  ('Phobe Apperson Hearst Elementary School', Decimal('0.92')),
#  ('Francis Scott Key Elementary School', Decimal('0.92')),
#  ('Pablo Casals Elementary School', Decimal('0.92')),
#  ('William H King Elementary School', Decimal('0.92')),
#  ('Charles Kozminski Elementary Community Academy', Decimal('0.92')),
#  ('Leslie Lewis Elementary School', Decimal('0.92')),
#  ('Roswell B Mason Elementary School', Decimal('0.92')),
#  ('Horatio May Elementary Community Academy', Decimal('0.92')),
#  ('Garrett A Morgan Elementary School', Decimal('0.92')),
#  ('Daniel C Beard Elementary School', Decimal('0.92')),
#  ("Isabelle C O'Keeffe Elementary School", Decimal('0.92')),
#  ('Francis W Parker Elementary Community Academy', Decimal('0.92')),
#  ('William Penn Elementary School', Decimal('0.92')),
#  ('Nathaniel Pope Elementary School', Decimal('0.92')),
#  ('Paul Revere Elementary School', Decimal('0.92')),
#  ('William T Sherman Elementary School', Decimal('0.92')),
#  ('Jesse Sherwood Elementary School', Decimal('0.92')),
#  ('Theophilus Schmid Elementary School', Decimal('0.92')),
#  ('John M Smyth Elementary School', Decimal('0.92')),
#  ('James N Thorp Elementary School', Decimal('0.92')),
#  ('Mildred I Lavizzo Elementary School', Decimal('0.92')),
#  ('James Wadsworth Elementary School', Decimal('0.92')),
#  ('Daniel S Wentworth Elementary School', Decimal('0.92')),
#  ('John Whistler Elementary School', Decimal('0.92')),
#  ('Williams Multiplex Elementary School', Decimal('0.92')),
#  ('Carrie Jacobs Bond Elementary School', Decimal('0.92')),
#  ('Guglielmo Marconi Elementary Community Academy', Decimal('0.92')),
#  ('Walter Reed Elementary School', Decimal('0.92')),
#  ('Ignance Paderewski Elementary Learning Academy', Decimal('0.92')),
#  ('Henry O Tanner Elementary School', Decimal('0.92')),
#  ('Granville T Woods Math & Science Academy Elementary School', Decimal('0.92')),
#  ('Genevieve Melody Elementary School', Decimal('0.92')),
#  ('William A Hinton Elementary School', Decimal('0.92')),
#  ('Phoenix Military Academy High School', Decimal('0.92')),
#  ('Carter G Woodson South Elementary School', Decimal('0.92')),
#  ('Bronzeville Scholastic Academy High School', Decimal('0.92')),
#  ('Infinity Math Science and Technology High School', Decimal('0.92')),
#  ('World Language Academy High School', Decimal('0.92')),
#  ('Eric Solorio Academy High School', Decimal('0.92')),
#  ('Ellen H Richards Career Academy High School', Decimal('0.91')),
#  ('Milton Brunson Math & Science Specialty Elementary School ', Decimal('0.91')),
#  ('William W Carter Elementary School', Decimal('0.91')),
#  ('George Washington Carver Primary School', Decimal('0.91')),
#  ('Dewey Elementary Academy of Fine Arts', Decimal('0.91')),
#  ('James R Doolittle Jr Elementary School', Decimal('0.91')),
#  ('Jesse Owens Elementary Community Academy', Decimal('0.91')),
#  ('Thomas A Hendricks Elementary Community Academy', Decimal('0.91')),
#  ('Theodore Herzl Elementary School', Decimal('0.91')),
#  ('Miriam G Canter Middle School', Decimal('0.91')),
#  ('Lawndale Elementary Community Academy', Decimal('0.91')),
#  ('Arthur A Libby Elementary School', Decimal('0.91')),
#  ('Robert H Lawrence Elementary School', Decimal('0.91')),
#  ('George Manierre Elementary School', Decimal('0.91')),
#  ('Brian Piccolo Elementary Specialty School', Decimal('0.91')),
#  ('Francis Parkman Elementary School', Decimal('0.91')),
#  ('Austin O Sexton Elementary School', Decimal('0.91')),
#  ('George W Tilton Elementary School', Decimal('0.91')),
#  ('West Pullman Elementary School', Decimal('0.91')),
#  ('Matthew A Henson Elementary School', Decimal('0.91')),
#  ('Julia C Lathrop Elementary School', Decimal('0.91')),
#  ('Jackie Robinson Elementary School', Decimal('0.91')),
#  ('Benjamin Banneker Elementary School', Decimal('0.91')),
#  ('Irvin C Mollison Elementary School', Decimal('0.91')),
#  ('Anthony Overton Elementary School', Decimal('0.91')),
#  ('Ronald E McNair Elementary School', Decimal('0.91')),
#  ('Simon Guggenheim Elementary School', Decimal('0.91')),
#  ('Amos Alonzo Stagg Elementary School', Decimal('0.91')),
#  ('Daniel Hale Williams Prep School of Medicine', Decimal('0.91')),
#  ('Collins Academy High School', Decimal('0.91')),
#  ('Marine Military Math and Science Academy ', Decimal('0.91')),
#  ('Northside Learning Center High School', Decimal('0.90')),
#  ('Chicago Military Academy High School', Decimal('0.90')),
#  ('Robert Emmet Elementary School', Decimal('0.90')),
#  ('Enrico Fermi Elementary School', Decimal('0.90')),
#  ('Alfred David Kohn Elementary School', Decimal('0.90')),
#  ('Parkside Elementary Community Academy', Decimal('0.90')),
#  ('Songhai Elementary Learning Institute', Decimal('0.90')),
#  ('William K New Sullivan Elementary School', Decimal('0.90')),
#  ('Elihu Yale Elementary School', Decimal('0.90')),
#  ('Florence B Price Elementary School', Decimal('0.90')),
#  ('Langston Hughes Elementary School', Decimal('0.90')),
#  ('Mason High School', Decimal('0.90')),
#  ('North-Grand High School', Decimal('0.89')),
#  ('Thomas Kelly High School', Decimal('0.89')),
#  ('William Howard Taft High School', Decimal('0.89')),
#  ('Gurdon S Hubbard High School', Decimal('0.89')),
#  ('Edmond Burke Elementary School', Decimal('0.89')),
#  ('Charles R Henderson Elementary School', Decimal('0.89')),
#  ('Edward Jenner Elementary Academy of the Arts', Decimal('0.89')),
#  ('Jane A Neil Elementary School', Decimal('0.89')),
#  ("Luke O'Toole Elementary School", Decimal('0.89')),
#  ('Betsy Ross Elementary School', Decimal('0.89')),
#  ('Multicultural Academy of Scholarship', Decimal('0.89')),
#  ('Uplift Community High School', Decimal('0.89')),
#  ('Lake View High School', Decimal('0.88')),
#  ('Stephen T Mather High School', Decimal('0.88')),
#  ('Kenwood Academy High School', Decimal('0.88')),
#  ('Jacqueline B Vaughn Occupational High School', Decimal('0.88')),
#  ('Emmett Louis Till Math and Science Academy', Decimal('0.88')),
#  ('Arthur R Ashe Elementary School', Decimal('0.88')),
#  ('Greater Lawndale High School For Social Justice', Decimal('0.88')),
#  ('Gwendolyn Brooks College Preparatory Academy High School', Decimal('0.87')),
#  ('Friedrich W von Steuben Metropolitan Science High School', Decimal('0.87')),
#  ('Oliver Wendell Holmes Elementary School', Decimal('0.87')),
#  ('TEAM Englewood Community Academy High School', Decimal('0.87')),
#  ('Charles Allen Prosser Career Academy High School', Decimal('0.86')),
#  ('David G Farragut Career Academy High School', Decimal('0.86')),
#  ('Southside Occupational Academy High School', Decimal('0.86')),
#  ('Ray Graham Training Center High School', Decimal('0.86')),
#  ('Walter S Christopher Elementary School', Decimal('0.86')),
#  ('Emil G Hirsch Metropolitan High School', Decimal('0.85')),
#  ('Lincoln Park High School', Decimal('0.85')),
#  ('Marie Sklodowska Curie Metropolitan High School', Decimal('0.85')),
#  ('VOISE Academy High School', Decimal('0.85')),
#  ('Edwin G Foreman High School', Decimal('0.84')),
#  ('Morgan Park High School', Decimal('0.84')),
#  ('Benito Juarez Community Academy High School', Decimal('0.84')),
#  ('John F Kennedy High School', Decimal('0.83')),
#  ('Kate S Buckingham Special Education Center', Decimal('0.83')),
#  ('Theodore Roosevelt High School', Decimal('0.82')),
#  ('Nicholas Senn High School', Decimal('0.82')),
#  ('Roger C Sullivan High School', Decimal('0.82')),
#  ('Roald Amundsen High School', Decimal('0.81')),
#  ('John M Harlan Community Academy High School', Decimal('0.81')),
#  ('Carl Schurz High School', Decimal('0.81')),
#  ('George Washington High School', Decimal('0.80')),
#  ('Moses Montefiore Special Elementary School', Decimal('0.80')),
#  ('Near North Elementary School', Decimal('0.80')),
#  ('Blair Early Childhood Center', Decimal('0.80')),
#  ('Wilma Rudolph Elementary Learning Center', Decimal('0.80')),
#  ('Al Raby High School', Decimal('0.80')),
#  ('Neal F Simeon Career Academy High School', Decimal('0.79')),
#  ('Charles P Steinmetz Academic Centre High School', Decimal('0.79')),
#  ('Michele Clark Academic Prep Magnet High School', Decimal('0.79')),
#  ('Frederick A Douglass Academy High School', Decimal('0.79')),
#  ('John Hancock College Preparatory High School', Decimal('0.78')),
#  ('Edward Tilden Career Community Academy High School', Decimal('0.78')),
#  ('Paul Laurence Dunbar Career Academy High School', Decimal('0.77')),
#  ('Austin Business and Entrepreneurship Academy High School', Decimal('0.76')),
#  ('New Millennium High School of Health at Bowen', Decimal('0.76')),
#  ('William J Bogan High School', Decimal('0.75')),
#  ('Percy L Julian High School', Decimal('0.75')),
#  ('Christian Fenger Academy High School', Decimal('0.74')),
#  ('Paul Robeson High School', Decimal('0.74')),
#  ('Kelvyn Park High School', Decimal('0.74')),
#  ('John Marshall Metropolitan High School', Decimal('0.74')),
#  ('Wells Community Academy High School', Decimal('0.74')),
#  ('Gage Park High School', Decimal('0.73')),
#  ('William Rainey Harper High School', Decimal('0.73')),
#  ('Hope College Preparatory High School', Decimal('0.72')),
#  ('Frederick Stock Elementary School', Decimal('0.72')),
#  ('High School of Leadership at South Shore', Decimal('0.72')),
#  ('Hyde Park Academy High School', Decimal('0.71')),
#  ('George H Corliss High School', Decimal('0.71')),
#  ('Roberto Clemente Community Academy High School', Decimal('0.70')),
#  ('Austin Polytechnical Academy High School', Decimal('0.70')),
#  ('Chicago Vocational Career Academy High School', Decimal('0.69')),
#  ('Manley Career Academy High School', Decimal('0.67')),
#  ('Orr Academy High School', Decimal('0.66')),
#  ('Wendell Phillips Academy High School', Decimal('0.63')),
#  ('Dyett High School', Decimal('0.63')),
#  ('Barbara Vick Early Childhood & Family Center', Decimal('0.61')),
#  ('Richard T Crane Technical Preparatory High School', Decimal('0.58'))]

# %% [markdown]
# **Problem 7 alternative solution: First use the CAST() function to cast it as a DECIMAL or DOUBLE, i.e:`CAST("Column_Name" as DOUBLE)` or `CAST("Column_Name" as DECIMAL)`.**

# %%
# %%sql
#
# select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE
#     from CHICAGO_PUBLIC_SCHOOLS
#     where cast(replace(AVERAGE_STUDENT_ATTENDANCE, '%', '') as double) < 70
#     order by AVERAGE_STUDENT_ATTENDANCE desc
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 565 rows affected.
# [('Rachel Carson Elementary School', Decimal('0.98')),
#  ('John Charles Haines Elementary School', Decimal('0.98')),
#  ('Annie Keller Elementary Gifted Magnet School', Decimal('0.98')),
#  ('Edgar Allan Poe Elementary Classical School', Decimal('0.98')),
#  ('James Ward Elementary School', Decimal('0.98')),
#  ('Orozco Fine Arts & Sciences Elementary School', Decimal('0.98')),
#  ('Louisa May Alcott Elementary School', Decimal('0.97')),
#  ('Thomas A Edison Regional Gifted Center Elementary School', Decimal('0.97')),
#  ('Augustus H Burley Elementary School', Decimal('0.97')),
#  ('Little Village Elementary School', Decimal('0.97')),
#  ('Frederic Chopin Elementary School', Decimal('0.97')),
#  ('Edgebrook Elementary School', Decimal('0.97')),
#  ('Eugene Field Elementary School', Decimal('0.97')),
#  ('Frank W Gunsaulus Elementary Scholastic Academy', Decimal('0.97')),
#  ('Emiliano Zapata Elementary Academy', Decimal('0.97')),
#  ('Hawthorne Elementary Scholastic Academy', Decimal('0.97')),
#  ('Robert Healy Elementary School', Decimal('0.97')),
#  ('William G Hibbard Elementary School', Decimal('0.97')),
#  ('Maria Saucedo Elementary Scholastic Academy', Decimal('0.97')),
#  ('LaSalle Elementary Language Academy', Decimal('0.97')),
#  ('Andrew Jackson Elementary Language Academy', Decimal('0.97')),
#  ('James B McPherson Elementary School', Decimal('0.97')),
#  ('Mark Sheridan Elementary Math & Science Academy', Decimal('0.97')),
#  ('Oriole Park Elementary School', Decimal('0.97')),
#  ('William Bishop Owen Scholastic Academy Elementary School', Decimal('0.97')),
#  ('Helen Peirce International Studies Elementary School', Decimal('0.97')),
#  ('Ambrose Plamondon Elementary School', Decimal('0.97')),
#  ('Frank W Reilly Elementary School', Decimal('0.97')),
#  ('Sidney Sawyer Elementary School', Decimal('0.97')),
#  ('James Shields Elementary School', Decimal('0.97')),
#  ('Mark Skinner Elementary School', Decimal('0.97')),
#  ('John H Vanderpoel Elementary Magnet School', Decimal('0.97')),
#  ('Albany Park Multicultural Academy', Decimal('0.97')),
#  ('Joseph Brennemann Elementary School', Decimal('0.97')),
#  ('Lenart Elementary Regional Gifted Center', Decimal('0.97')),
#  ('Calmeca Academy of Fine Arts and Dual Language', Decimal('0.97')),
#  ('DeVry University Advantage Academy High School', Decimal('0.97')),
#  ('Suder Montessori Magnet Elementary School', Decimal('0.97')),
#  ('Frazier Prospective IB Magnet Elementary School', Decimal('0.97')),
#  ('Disney II Magnet School', Decimal('0.97')),
#  ('Federico Garcia Lorca Elementary School', Decimal('0.97')),
#  ('Albert G Lane Technical High School', Decimal('0.96')),
#  ('Northside College Preparatory High School', Decimal('0.96')),
#  ('Jane Addams Elementary School', Decimal('0.96')),
#  ('George Armstrong International Studies Elementary School', Decimal('0.96')),
#  ('John J Audubon Elementary School', Decimal('0.96')),
#  ('Alice L Barnard Computer Math & Science Center Elementary School', Decimal('0.96')),
#  ('Newton Bateman Elementary School', Decimal('0.96')),
#  ('Jean Baptiste Beaubien Elementary School', Decimal('0.96')),
#  ('Alexander Graham Bell Elementary School', Decimal('0.96')),
#  ('James G Blaine Elementary School', Decimal('0.96')),
#  ('Daniel Boone Elementary School', Decimal('0.96')),
#  ('Norman A Bridge Elementary School', Decimal('0.96')),
#  ('Burnham Elementary Inclusive Academy', Decimal('0.96')),
#  ('Rosario Castellanos Elementary School', Decimal('0.96')),
#  ('Jonathan Burr Elementary School', Decimal('0.96')),
#  ('John C Burroughs Elementary School', Decimal('0.96')),
#  ('Arthur E Canty Elementary School', Decimal('0.96')),
#  ('Horace Greeley Elementary School', Decimal('0.96')),
#  ('Christopher Columbus Elementary School', Decimal('0.96')),
#  ('Jordan Elementary Community School', Decimal('0.96')),
#  ('John C Coonley Elementary School', Decimal('0.96')),
#  ('Peter Cooper Elementary Dual Language Academy', Decimal('0.96')),
#  ('Manuel Perez Elementary School', Decimal('0.96')),
#  ('Everett McKinley Dirksen Elementary School', Decimal('0.96')),
#  ('Charles R Darwin Elementary School', Decimal('0.96')),
#  ('Charles Gates Dawes Elementary School', Decimal('0.96')),
#  ('Stephen Decatur Classical Elementary School', Decimal('0.96')),
#  ('William E Dever Elementary School', Decimal('0.96')),
#  ('John C Dore Elementary School', Decimal('0.96')),
#  ('Turner-Drew Elementary Language Academy', Decimal('0.96')),
#  ('Christian Ebinger Elementary School', Decimal('0.96')),
#  ('Laughlin Falconer Elementary School', Decimal('0.96')),
#  ('Gerald Delgado Kanoon Elementary Magnet School', Decimal('0.96')),
#  ('Franklin Elementary Fine Arts Center', Decimal('0.96')),
#  ('Joseph E Gary Elementary School', Decimal('0.96')),
#  ('Johann W von Goethe Elementary School', Decimal('0.96')),
#  ('Virgil Grissom Elementary School', Decimal('0.96')),
#  ('William C Goudy Elementary School', Decimal('0.96')),
#  ('William P Gray Elementary School', Decimal('0.96')),
#  ('Josefa Ortiz De Dominguez Elementary School', Decimal('0.96')),
#  ('Ariel Elementary Community Academy', Decimal('0.96')),
#  ('Nathanael Greene Elementary School', Decimal('0.96')),
#  ('Walter Q Gresham Elementary School', Decimal('0.96')),
#  ('Helge A Haugan Elementary School', Decimal('0.96')),
#  ('Stephen K Hayt Elementary School', Decimal('0.96')),
#  ('Agustin Lara Elementary Academy', Decimal('0.96')),
#  ('Julia Ward Howe Elementary School of Excellence', Decimal('0.96')),
#  ('Minnie Mars Jamieson Elementary School', Decimal('0.96')),
#  ('Pilsen Elementary Community Academy', Decimal('0.96')),
#  ('Joseph Jungman Elementary School', Decimal('0.96')),
#  ('Kate S Kellogg Elementary School', Decimal('0.96')),
#  ('Joyce Kilmer Elementary School', Decimal('0.96')),
#  ('Lazaro Cardenas Elementary School', Decimal('0.96')),
#  ('Abraham Lincoln Elementary School', Decimal('0.96')),
#  ('Carl von Linne Elementary School', Decimal('0.96')),
#  ('Henry D Lloyd Elementary School', Decimal('0.96')),
#  ('Josephine C Locke Elementary School', Decimal('0.96')),
#  ('Mary Lyon Elementary School', Decimal('0.96')),
#  ('John L Marsh Elementary School', Decimal('0.96')),
#  ('Cyrus H McCormick Elementary School', Decimal('0.96')),
#  ('James E McDade Elementary Classical School', Decimal('0.96')),
#  ('Ellen Mitchell Elementary School', Decimal('0.96')),
#  ('Inter-American Elementary Magnet School', Decimal('0.96')),
#  ('Mount Greenwood Elementary School', Decimal('0.96')),
#  ('John B Murphy Elementary School', Decimal('0.96')),
#  ('Phillip Murray Elementary Language Academy', Decimal('0.96')),
#  ('Louis Nettelhorst Elementary School', Decimal('0.96')),
#  ('Florence Nightingale Elementary School', Decimal('0.96')),
#  ('William P Nixon Elementary School', Decimal('0.96')),
#  ('Norwood Park Elementary School', Decimal('0.96')),
#  ('William J Onahan Elementary School', Decimal('0.96')),
#  ('James Otis Elementary School', Decimal('0.96')),
#  ('John Palmer Elementary School', Decimal('0.96')),
#  ('Ferdinand Peck Elementary School', Decimal('0.96')),
#  ('Washington Irving Elementary School', Decimal('0.96')),
#  ('Harold Washington Elementary School', Decimal('0.96')),
#  ('Irma C Ruiz Elementary School', Decimal('0.96')),
#  ('John J Pershing Elementary Humanities Magnet', Decimal('0.96')),
#  ('Mary Gage Peterson Elementary School', Decimal('0.96')),
#  ('Josiah Pickard Elementary School', Decimal('0.96')),
#  ('Pulaski International Academy Elmentary School', Decimal('0.96')),
#  ('Peter A Reinberg Elementary School', Decimal('0.96')),
#  ('Philip Rogers Elementary School', Decimal('0.96')),
#  ('Martin A Ryerson Elementary School', Decimal('0.96')),
#  ('Sauganash Elementary School', Decimal('0.96')),
#  ('Harriet E Sayre Elementary Language Academy', Decimal('0.96')),
#  ('Jonathan Y Scammon Elementary School', Decimal('0.96')),
#  ('Franz Peter Schubert Elementary School', Decimal('0.96')),
#  ('William H Seward Communication Arts Academy Elementary School', Decimal('0.96')),
#  ('Washington D Smyser Elementary School', Decimal('0.96')),
#  ('Hannah G Solomon Elementary School', Decimal('0.96')),
#  ('John Spry Elementary Community School', Decimal('0.96')),
#  ('Adlai E Stevenson Elementary School', Decimal('0.96')),
#  ('Stone Elementary Scholastic Academy', Decimal('0.96')),
#  ('Elizabeth H Sutherland Elementary School', Decimal('0.96')),
#  ('George B Swift Elementary Specialty School', Decimal('0.96')),
#  ('Mancel Talcott Elementary School', Decimal('0.96')),
#  ('Johnnie Colemon Elementary Academy', Decimal('0.96')),
#  ('Ole A Thorp Elementary Scholastic Academy', Decimal('0.96')),
#  ('Enrico Tonti Elementary School', Decimal('0.96')),
#  ('Mark Twain Elementary School', Decimal('0.96')),
#  ('Alessandro Volta Elementary School', Decimal('0.96')),
#  ('George Washington Elementary School', Decimal('0.96')),
#  ('Thomas J Waters Elementary School', Decimal('0.96')),
#  ('Socorro Sandoval Elementary School', Decimal('0.96')),
#  ('Eli Whitney Elementary School', Decimal('0.96')),
#  ('Wildwood Elementary School', Decimal('0.96')),
#  ('John Calhoun North Elementary School', Decimal('0.96')),
#  ('Chicago Academy Elementary School', Decimal('0.96')),
#  ('Talman Elementary School', Decimal('0.96')),
#  ('Adam Clayton Powell Paideia Community Academy Elementary School', Decimal('0.96')),
#  ('New Field Elementary School', Decimal('0.96')),
#  ('Ashburn Community Elementary School', Decimal('0.96')),
#  ('Benjamin E Mays Elementary Academy', Decimal('0.96')),
#  ('Mary E McDowell Elementary School', Decimal('0.96')),
#  ('Amelia Earhart Options for Knowledge Elementary School', Decimal('0.96')),
#  ('Brighton Park Elementary School', Decimal('0.96')),
#  ('Evergreen Academy Middle School', Decimal('0.96')),
#  ('Robert A Black Magnet Elementary School', Decimal('0.96')),
#  ('North River Elementary School', Decimal('0.96')),
#  ('Spry Community Links High School', Decimal('0.96')),
#  ('Walt Disney Magnet Elementary School', Decimal('0.96')),
#  ('Pershing West Middle School', Decimal('0.96')),
#  ('Tarkington School of Excellence Elementary School', Decimal('0.96')),
#  ('Edison Park Elementary School', Decimal('0.96')),
#  ('Irene C. Hernandez Middle School for the Advancement of Science', Decimal('0.96')),
#  ('Skinner North', Decimal('0.96')),
#  ('Mariano Azuela Elementary School', Decimal('0.96')),
#  ('Whitney M Young Magnet High School', Decimal('0.95')),
#  ('Louis A Agassiz Elementary School', Decimal('0.95')),
#  ('Crispus Attucks Elementary School', Decimal('0.95')),
#  ('John Barry Elementary School', Decimal('0.95')),
#  ('Jacob Beidler Elementary School', Decimal('0.95')),
#  ('Hiram H Belding Elementary School', Decimal('0.95')),
#  ('Scott Joplin Elementary School', Decimal('0.95')),
#  ('Lionel Hampton Fine & Performing Arts Elementary School', Decimal('0.95')),
#  ('Alex Haley Elementary Academy', Decimal('0.95')),
#  ('Lorenz Brentano Math & Science Academy Elementary School', Decimal('0.95')),
#  ('Lyman A Budlong Elementary School', Decimal('0.95')),
#  ('Luther Burbank Elementary School', Decimal('0.95')),
#  ('Burnside Elementary Scholastic Academy', Decimal('0.95')),
#  ('Michael M Byrne Elementary School', Decimal('0.95')),
#  ('Andrew Carnegie Elementary School', Decimal('0.95')),
#  ('Carroll-Rosenwald Specialty Elementary School', Decimal('0.95')),
#  ('Eliza Chappell Elementary School', Decimal('0.95')),
#  ('Salmon P Chase Elementary School', Decimal('0.95')),
#  ('Henry Clay Elementary School', Decimal('0.95')),
#  ('Grover Cleveland Elementary School', Decimal('0.95')),
#  ('DeWitt Clinton Elementary School', Decimal('0.95')),
#  ('Henry R Clissold Elementary School', Decimal('0.95')),
#  ('Edward Coles Elementary Language Academy', Decimal('0.95')),
#  ('Daniel J Corkery Elementary School', Decimal('0.95')),
#  ('Nathan S Davis Elementary School', Decimal('0.95')),
#  ('Arthur Dixon Elementary School', Decimal('0.95')),
#  ('Thomas Drummond Elementary School', Decimal('0.95')),
#  ('John F Eberhart Elementary School', Decimal('0.95')),
#  ('Ralph H Metcalfe Elementary Community Academy', Decimal('0.95')),
#  ('Richard Edwards Elementary School', Decimal('0.95')),
#  ('Leif Ericson Elementary Scholastic Academy', Decimal('0.95')),
#  ('Edward Everett Elementary School', Decimal('0.95')),
#  ('Telpochcalli Elementary School', Decimal('0.95')),
#  ('Belmont-Cragin Elementary School', Decimal('0.95')),
#  ('Joseph Kellman Corporate Community Elementary School', Decimal('0.95')),
#  ('Robert Fulton Elementary School', Decimal('0.95')),
#  ('Frederick Funston Elementary School', Decimal('0.95')),
#  ('Matthew Gallistel Elementary Language Academy', Decimal('0.95')),
#  ('John W Garvy Elementary School', Decimal('0.95')),
#  ('John Milton Gregory Elementary School', Decimal('0.95')),
#  ('Robert L Grimes Elementary School', Decimal('0.95')),
#  ('Nathan Hale Elementary School', Decimal('0.95')),
#  ('Alexander Hamilton Elementary School', Decimal('0.95')),
#  ('Charles G Hammond Elementary School', Decimal('0.95')),
#  ('William F Finkl Elementary School', Decimal('0.95')),
#  ('James Hedges Elementary School', Decimal('0.95')),
#  ('Patrick Henry Elementary School', Decimal('0.95')),
#  ('South Loop Elementary School', Decimal('0.95')),
#  ('Rufus M Hitch Elementary School', Decimal('0.95')),
#  ('Charles N Holden Elementary School', Decimal('0.95')),
#  ('Thomas Hoyne Elementary School', Decimal('0.95')),
#  ('Edward N Hurley Elementary School', Decimal('0.95')),
#  ('Galileo Math & Science Scholastic Academy Elementary School', Decimal('0.95')),
#  ('Friedrich Ludwig Jahn Elementary School', Decimal('0.95')),
#  ('Joshua D Kershaw Elementary School', Decimal('0.95')),
#  ('John H Kinzie Elementary School', Decimal('0.95')),
#  ('Rudyard Kipling Elementary School', Decimal('0.95')),
#  ('Rodolfo Lozano Bilingual & International Center Elementary School', Decimal('0.95')),
#  ('Joseph Lovett Elementary School', Decimal('0.95')),
#  ('James Madison Elementary School', Decimal('0.95')),
#  ('Oscar F Mayer Elementary School', Decimal('0.95')),
#  ('William J & Charles H Mayo Elementary School', Decimal('0.95')),
#  ('Hanson Park Elementary School', Decimal('0.95')),
#  ('James Monroe Elementary School', Decimal('0.95')),
#  ('Wolfgang A Mozart Elementary School', Decimal('0.95')),
#  ('Henry H Nash Elementary School', Decimal('0.95')),
#  ('Walter L Newberry Math & Science Academy Elementary School', Decimal('0.95')),
#  ('Alfred Nobel Elementary School', Decimal('0.95')),
#  ('William B Ogden Elementary School', Decimal('0.95')),
#  ('Park Manor Elementary School', Decimal('0.95')),
#  ('Louis Pasteur Elementary School', Decimal('0.95')),
#  ('Elizabeth Peabody Elementary School', Decimal('0.95')),
#  ('Ernst Prussing Elementary School', Decimal('0.95')),
#  ('Ravenswood Elementary School', Decimal('0.95')),
#  ('William H Ray Elementary School', Decimal('0.95')),
#  ('Cesar E Chavez Multicultural Academic Center Elementary School', Decimal('0.95')),
#  ('Columbia Explorers Elementary Academy', Decimal('0.95')),
#  ('Beulah Shoesmith Elementary School', Decimal('0.95')),
#  ('Graeme Stewart Elementary School', Decimal('0.95')),
#  ('Dunne Technology Academy', Decimal('0.95')),
#  ('Joseph Stockton Elementary School', Decimal('0.95')),
#  ('Douglas Taylor Elementary School', Decimal('0.95')),
#  ('Francisco I Madero Middle School', Decimal('0.95')),
#  ('John A Walsh Elementary School', Decimal('0.95')),
#  ('Joseph Warren Elementary School', Decimal('0.95')),
#  ('Daniel Webster Elementary School', Decimal('0.95')),
#  ('John Greenleaf Whittier Elementary School', Decimal('0.95')),
#  ('A.N. Pritzker School', Decimal('0.95')),
#  ('National Teachers Elementary Academy', Decimal('0.95')),
#  ('Richard J Daley Elementary Academy', Decimal('0.95')),
#  ('Edward Beasley Elementary Magnet Academic Center', Decimal('0.95')),
#  ('Rueben Salazar Elementary Bilingual Center', Decimal('0.95')),
#  ('Willa Cather Elementary School', Decimal('0.95')),
#  ('James Weldon Johnson Elementary School', Decimal('0.95')),
#  ('Richard Henry Lee Elementary School', Decimal('0.95')),
#  ('Thomas J Higgins Elementary Community Academy', Decimal('0.95')),
#  ('Jose De Diego Elementary Community Academy', Decimal('0.95')),
#  ('Ana Roque de Duprey Elementary School', Decimal('0.95')),
#  ('Logandale Middle School', Decimal('0.95')),
#  ('Albert R Sabin Elementary Magnet School', Decimal('0.95')),
#  ('Durkin Park Elementary School', Decimal('0.95')),
#  ('Mary E Courtenay Elementary Language Arts Center', Decimal('0.95')),
#  ('Medgar Evers Elementary School', Decimal('0.95')),
#  ('LaSalle II Magnet Elementary School', Decimal('0.95')),
#  ('Dr Jorge Prieto Math and Science', Decimal('0.95')),
#  ('Marvin Camras Elementary School', Decimal('0.95')),
#  ('West Ridge Elementary School', Decimal('0.95')),
#  ('William Jones College Preparatory High School', Decimal('0.94')),
#  ('George Westinghouse High School', Decimal('0.94')),
#  ('Phillip D Armour Elementary School', Decimal('0.94')),
#  ('Ames Middle School', Decimal('0.94')),
#  ('George Rogers Clark Elementary School', Decimal('0.94')),
#  ('George F Cassell Elementary School', Decimal('0.94')),
#  ('Thomas Chalmers Specialty Elementary School', Decimal('0.94')),
#  ('John W Cook Elementary School', Decimal('0.94')),
#  ('Charles S Deneen Elementary School', Decimal('0.94')),
#  ('Mary Mapes Dodge Elementary Renaissance Academy', Decimal('0.94')),
#  ('John B Drake Elementary School', Decimal('0.94')),
#  ('Charles W Earle Elementary School', Decimal('0.94')),
#  ('George W Curtis Elementary School', Decimal('0.94')),
#  ('James B Farnsworth Elementary School', Decimal('0.94')),
#  ('Foster Park Elementary School', Decimal('0.94')),
#  ('Samuel Gompers Fine Arts Options Elementary School', Decimal('0.94')),
#  ('Ninos Heroes Elementary Academic Center', Decimal('0.94')),
#  ('John H Hamline Elementary School', Decimal('0.94')),
#  ('Sharon Christa McAuliffe Elementary School', Decimal('0.94')),
#  ('Bret Harte Elementary School', Decimal('0.94')),
#  ('Woodlawn Community Elementary School', Decimal('0.94')),
#  ('Helen M Hefferan Elementary School', Decimal('0.94')),
#  ('Paul Cuffe Math-Science Technology Academy Elementary School', Decimal('0.94')),
#  ('Countee Cullen Elementary School', Decimal('0.94')),
#  ('Charles Evans Hughes Elementary School', Decimal('0.94')),
#  ('Jean D Lafayette Elementary School', Decimal('0.94')),
#  ('Wendell E Green Elementary School', Decimal('0.94')),
#  ('Francis M McKay Elementary School', Decimal('0.94')),
#  ('Ronald Brown Elementary Community Academy', Decimal('0.94')),
#  ('West Park Elementary Academy', Decimal('0.94')),
#  ('Richard J Oglesby Elementary School', Decimal('0.94')),
#  ('Marcus Moziah Garvey Elementary School', Decimal('0.94')),
#  ('John T Pirie Fine Arts & Academic Center Elementary School', Decimal('0.94')),
#  ('Portage Park Elementary School', Decimal('0.94')),
#  ('William H Prescott Elementary School', Decimal('0.94')),
#  ('George M Pullman Elementary School', Decimal('0.94')),
#  ('William C Reavis Math & Science Specialty Elementary School', Decimal('0.94')),
#  ('Martha Ruggles Elementary School', Decimal('0.94')),
#  ('Arna Wendell Bontemps Elementary School', Decimal('0.94')),
#  ('Harriet Beecher Stowe Elementary School', Decimal('0.94')),
#  ('Charles Sumner  Math & Science Community Acad Elementary School', Decimal('0.94')),
#  ('Lyman Trumbull Elementary School', Decimal('0.94')),
#  ('Richard Yates Elementary School', Decimal('0.94')),
#  ('Ella Flagg Young Elementary School', Decimal('0.94')),
#  ('Ludwig Van Beethoven Elementary School', Decimal('0.94')),
#  ('Robert Nathaniel Dett Elementary School', Decimal('0.94')),
#  ('Dvorak Technology Academy', Decimal('0.94')),
#  ('Morton School of Excellence', Decimal('0.94')),
#  ('John Foster Dulles Elementary School', Decimal('0.94')),
#  ('John T McCutcheon Elementary School', Decimal('0.94')),
#  ('Edward White Elementary Career Academy', Decimal('0.94')),
#  ('Thurgood Marshall Middle School', Decimal('0.94')),
#  ('Ogden International High School', Decimal('0.94')),
#  ('South Shore Fine Arts Academy', Decimal('0.94')),
#  ('Walter Payton College Preparatory High School', Decimal('0.93')),
#  ('Dr  Martin Luther King  Jr  College Prep High School', Decimal('0.93')),
#  ('Chicago High School for Agricultural Sciences', Decimal('0.93')),
#  ('Nicholson Technology Academy', Decimal('0.93')),
#  ('Frank I Bennett Elementary School', Decimal('0.93')),
#  ('William H Brown Elementary School', Decimal('0.93')),
#  ('Charles S Brownell Elementary School', Decimal('0.93')),
#  ('Edward A Bouchet Math & Science Academy Elementary School', Decimal('0.93')),
#  ('Charles P Caldwell Academy of Math & Science Elementary School', Decimal('0.93')),
#  ('Daniel R Cameron Elementary School', Decimal('0.93')),
#  ('Ira F Aldridge Elementary School', Decimal('0.93')),
#  ('Crown Community Academy of Fine Arts Center Elementary School', Decimal('0.93')),
#  ('Edward C Delano Elementary School', Decimal('0.93')),
#  ('Edward K Ellington Elementary School', Decimal('0.93')),
#  ('Esmond Elementary School', Decimal('0.93')),
#  ('Fernwood Elementary School', Decimal('0.93')),
#  ('John Fiske Elementary School', Decimal('0.93')),
#  ('Fort Dearborn Elementary School', Decimal('0.93')),
#  ('Alexander Graham Elementary School', Decimal('0.93')),
#  ('John Harvard Elementary School of Excellence', Decimal('0.93')),
#  ('John Hay Elementary Community Academy', Decimal('0.93')),
#  ('Victor Herbert Elementary School', Decimal('0.93')),
#  ('James Russell Lowell Elementary School', Decimal('0.93')),
#  ('Northwest Middle School', Decimal('0.93')),
#  ('Horace Mann Elementary School', Decimal('0.93')),
#  ('Marquette Elementary School', Decimal('0.93')),
#  ('Michael Faraday Elementary School', Decimal('0.93')),
#  ('Fairfield Elementary Academy', Decimal('0.93')),
#  ('George B McClellan Elementary School', Decimal('0.93')),
#  ('Bernhard Moos Elementary School', Decimal('0.93')),
#  ('Donald Morrill Math & Science Elementary School', Decimal('0.93')),
#  ('Mount Vernon Elementary School', Decimal('0.93')),
#  ('Ida B Wells Preparatory Elementary Academy', Decimal('0.93')),
#  ('Laura S Ward Elementary School', Decimal('0.93')),
#  ('William H Ryder Math & Science Specialty Elementary School', Decimal('0.93')),
#  ('Louis Armstrong Math & Science Elementary School', Decimal('0.93')),
#  ('Arnold Mireles Elementary Academy', Decimal('0.93')),
#  ('John D Shoop Math-Science Technical Academy Elementary School', Decimal('0.93')),
#  ('Spencer Technology Academy', Decimal('0.93')),
#  ('Alexander von Humboldt Elementary School', Decimal('0.93')),
#  ('Dumas Technology Academy', Decimal('0.93')),
#  ('Jensen Elementary Scholastic Academy', Decimal('0.93')),
#  ('Oliver S Westcott Elementary School', Decimal('0.93')),
#  ('George Leland Elementary School', Decimal('0.93')),
#  ('Williams Preparatory Academy Middle School', Decimal('0.93')),
#  ('Chicago Academy High School', Decimal('0.93')),
#  ('Claremont Academy Elementary School', Decimal('0.93')),
#  ('Nathan R Goldblatt Elementary School', Decimal('0.93')),
#  ('William E B Dubois Elementary School', Decimal('0.93')),
#  ('Mary McLeod Bethune Elementary School', Decimal('0.93')),
#  ('Charles H Wacker Elementary School', Decimal('0.93')),
#  ('Oscar DePriest Elementary School', Decimal('0.93')),
#  ('Mahalia Jackson Elementary School', Decimal('0.93')),
#  ('Hyman G Rickover Naval Academy High School', Decimal('0.93')),
#  ('Robert Lindblom Math & Science Academy High School', Decimal('0.93')),
#  ('Air Force Academy High School', Decimal('0.93')),
#  ('Sir Miles Davis Magnet Elementary Academy', Decimal('0.93')),
#  ('Alcott High School for the Humanities', Decimal('0.93')),
#  ('George Washington Carver Military Academy High School', Decimal('0.92')),
#  ('John P Altgeld Elementary School', Decimal('0.92')),
#  ('Avalon Park Elementary School', Decimal('0.92')),
#  ('Clara Barton Elementary School', Decimal('0.92')),
#  ('Perkins Bass Elementary School', Decimal('0.92')),
#  ('Myra Bradwell Communications Arts & Sciences Elementary School', Decimal('0.92')),
#  ('Orville T Bright Elementary School', Decimal('0.92')),
#  ('Anna R. Langford Community Academy', Decimal('0.92')),
#  ('Elaine O Goodlow Elementary Magnet School', Decimal('0.92')),
#  ('Melville W Fuller Elementary School', Decimal('0.92')),
#  ('Stephen F Gale Elementary Community Academy', Decimal('0.92')),
#  ('Frank L Gillespie Elementary School', Decimal('0.92')),
#  ('Asa Philip Randolph Elementary School', Decimal('0.92')),
#  ('Wendell Smith Elementary School', Decimal('0.92')),
#  ('Phobe Apperson Hearst Elementary School', Decimal('0.92')),
#  ('Francis Scott Key Elementary School', Decimal('0.92')),
#  ('Pablo Casals Elementary School', Decimal('0.92')),
#  ('William H King Elementary School', Decimal('0.92')),
#  ('Charles Kozminski Elementary Community Academy', Decimal('0.92')),
#  ('Leslie Lewis Elementary School', Decimal('0.92')),
#  ('Roswell B Mason Elementary School', Decimal('0.92')),
#  ('Horatio May Elementary Community Academy', Decimal('0.92')),
#  ('Garrett A Morgan Elementary School', Decimal('0.92')),
#  ('Daniel C Beard Elementary School', Decimal('0.92')),
#  ("Isabelle C O'Keeffe Elementary School", Decimal('0.92')),
#  ('Francis W Parker Elementary Community Academy', Decimal('0.92')),
#  ('William Penn Elementary School', Decimal('0.92')),
#  ('Nathaniel Pope Elementary School', Decimal('0.92')),
#  ('Paul Revere Elementary School', Decimal('0.92')),
#  ('William T Sherman Elementary School', Decimal('0.92')),
#  ('Jesse Sherwood Elementary School', Decimal('0.92')),
#  ('Theophilus Schmid Elementary School', Decimal('0.92')),
#  ('John M Smyth Elementary School', Decimal('0.92')),
#  ('James N Thorp Elementary School', Decimal('0.92')),
#  ('Mildred I Lavizzo Elementary School', Decimal('0.92')),
#  ('James Wadsworth Elementary School', Decimal('0.92')),
#  ('Daniel S Wentworth Elementary School', Decimal('0.92')),
#  ('John Whistler Elementary School', Decimal('0.92')),
#  ('Williams Multiplex Elementary School', Decimal('0.92')),
#  ('Carrie Jacobs Bond Elementary School', Decimal('0.92')),
#  ('Guglielmo Marconi Elementary Community Academy', Decimal('0.92')),
#  ('Walter Reed Elementary School', Decimal('0.92')),
#  ('Ignance Paderewski Elementary Learning Academy', Decimal('0.92')),
#  ('Henry O Tanner Elementary School', Decimal('0.92')),
#  ('Granville T Woods Math & Science Academy Elementary School', Decimal('0.92')),
#  ('Genevieve Melody Elementary School', Decimal('0.92')),
#  ('William A Hinton Elementary School', Decimal('0.92')),
#  ('Phoenix Military Academy High School', Decimal('0.92')),
#  ('Carter G Woodson South Elementary School', Decimal('0.92')),
#  ('Bronzeville Scholastic Academy High School', Decimal('0.92')),
#  ('Infinity Math Science and Technology High School', Decimal('0.92')),
#  ('World Language Academy High School', Decimal('0.92')),
#  ('Eric Solorio Academy High School', Decimal('0.92')),
#  ('Ellen H Richards Career Academy High School', Decimal('0.91')),
#  ('Milton Brunson Math & Science Specialty Elementary School ', Decimal('0.91')),
#  ('William W Carter Elementary School', Decimal('0.91')),
#  ('George Washington Carver Primary School', Decimal('0.91')),
#  ('Dewey Elementary Academy of Fine Arts', Decimal('0.91')),
#  ('James R Doolittle Jr Elementary School', Decimal('0.91')),
#  ('Jesse Owens Elementary Community Academy', Decimal('0.91')),
#  ('Thomas A Hendricks Elementary Community Academy', Decimal('0.91')),
#  ('Theodore Herzl Elementary School', Decimal('0.91')),
#  ('Miriam G Canter Middle School', Decimal('0.91')),
#  ('Lawndale Elementary Community Academy', Decimal('0.91')),
#  ('Arthur A Libby Elementary School', Decimal('0.91')),
#  ('Robert H Lawrence Elementary School', Decimal('0.91')),
#  ('George Manierre Elementary School', Decimal('0.91')),
#  ('Brian Piccolo Elementary Specialty School', Decimal('0.91')),
#  ('Francis Parkman Elementary School', Decimal('0.91')),
#  ('Austin O Sexton Elementary School', Decimal('0.91')),
#  ('George W Tilton Elementary School', Decimal('0.91')),
#  ('West Pullman Elementary School', Decimal('0.91')),
#  ('Matthew A Henson Elementary School', Decimal('0.91')),
#  ('Julia C Lathrop Elementary School', Decimal('0.91')),
#  ('Jackie Robinson Elementary School', Decimal('0.91')),
#  ('Benjamin Banneker Elementary School', Decimal('0.91')),
#  ('Irvin C Mollison Elementary School', Decimal('0.91')),
#  ('Anthony Overton Elementary School', Decimal('0.91')),
#  ('Ronald E McNair Elementary School', Decimal('0.91')),
#  ('Simon Guggenheim Elementary School', Decimal('0.91')),
#  ('Amos Alonzo Stagg Elementary School', Decimal('0.91')),
#  ('Daniel Hale Williams Prep School of Medicine', Decimal('0.91')),
#  ('Collins Academy High School', Decimal('0.91')),
#  ('Marine Military Math and Science Academy ', Decimal('0.91')),
#  ('Northside Learning Center High School', Decimal('0.90')),
#  ('Chicago Military Academy High School', Decimal('0.90')),
#  ('Robert Emmet Elementary School', Decimal('0.90')),
#  ('Enrico Fermi Elementary School', Decimal('0.90')),
#  ('Alfred David Kohn Elementary School', Decimal('0.90')),
#  ('Parkside Elementary Community Academy', Decimal('0.90')),
#  ('Songhai Elementary Learning Institute', Decimal('0.90')),
#  ('William K New Sullivan Elementary School', Decimal('0.90')),
#  ('Elihu Yale Elementary School', Decimal('0.90')),
#  ('Florence B Price Elementary School', Decimal('0.90')),
#  ('Langston Hughes Elementary School', Decimal('0.90')),
#  ('Mason High School', Decimal('0.90')),
#  ('North-Grand High School', Decimal('0.89')),
#  ('Thomas Kelly High School', Decimal('0.89')),
#  ('William Howard Taft High School', Decimal('0.89')),
#  ('Gurdon S Hubbard High School', Decimal('0.89')),
#  ('Edmond Burke Elementary School', Decimal('0.89')),
#  ('Charles R Henderson Elementary School', Decimal('0.89')),
#  ('Edward Jenner Elementary Academy of the Arts', Decimal('0.89')),
#  ('Jane A Neil Elementary School', Decimal('0.89')),
#  ("Luke O'Toole Elementary School", Decimal('0.89')),
#  ('Betsy Ross Elementary School', Decimal('0.89')),
#  ('Multicultural Academy of Scholarship', Decimal('0.89')),
#  ('Uplift Community High School', Decimal('0.89')),
#  ('Lake View High School', Decimal('0.88')),
#  ('Stephen T Mather High School', Decimal('0.88')),
#  ('Kenwood Academy High School', Decimal('0.88')),
#  ('Jacqueline B Vaughn Occupational High School', Decimal('0.88')),
#  ('Emmett Louis Till Math and Science Academy', Decimal('0.88')),
#  ('Arthur R Ashe Elementary School', Decimal('0.88')),
#  ('Greater Lawndale High School For Social Justice', Decimal('0.88')),
#  ('Gwendolyn Brooks College Preparatory Academy High School', Decimal('0.87')),
#  ('Friedrich W von Steuben Metropolitan Science High School', Decimal('0.87')),
#  ('Oliver Wendell Holmes Elementary School', Decimal('0.87')),
#  ('TEAM Englewood Community Academy High School', Decimal('0.87')),
#  ('Charles Allen Prosser Career Academy High School', Decimal('0.86')),
#  ('David G Farragut Career Academy High School', Decimal('0.86')),
#  ('Southside Occupational Academy High School', Decimal('0.86')),
#  ('Ray Graham Training Center High School', Decimal('0.86')),
#  ('Walter S Christopher Elementary School', Decimal('0.86')),
#  ('Emil G Hirsch Metropolitan High School', Decimal('0.85')),
#  ('Lincoln Park High School', Decimal('0.85')),
#  ('Marie Sklodowska Curie Metropolitan High School', Decimal('0.85')),
#  ('VOISE Academy High School', Decimal('0.85')),
#  ('Edwin G Foreman High School', Decimal('0.84')),
#  ('Morgan Park High School', Decimal('0.84')),
#  ('Benito Juarez Community Academy High School', Decimal('0.84')),
#  ('John F Kennedy High School', Decimal('0.83')),
#  ('Kate S Buckingham Special Education Center', Decimal('0.83')),
#  ('Theodore Roosevelt High School', Decimal('0.82')),
#  ('Nicholas Senn High School', Decimal('0.82')),
#  ('Roger C Sullivan High School', Decimal('0.82')),
#  ('Roald Amundsen High School', Decimal('0.81')),
#  ('John M Harlan Community Academy High School', Decimal('0.81')),
#  ('Carl Schurz High School', Decimal('0.81')),
#  ('George Washington High School', Decimal('0.80')),
#  ('Moses Montefiore Special Elementary School', Decimal('0.80')),
#  ('Near North Elementary School', Decimal('0.80')),
#  ('Blair Early Childhood Center', Decimal('0.80')),
#  ('Wilma Rudolph Elementary Learning Center', Decimal('0.80')),
#  ('Al Raby High School', Decimal('0.80')),
#  ('Neal F Simeon Career Academy High School', Decimal('0.79')),
#  ('Charles P Steinmetz Academic Centre High School', Decimal('0.79')),
#  ('Michele Clark Academic Prep Magnet High School', Decimal('0.79')),
#  ('Frederick A Douglass Academy High School', Decimal('0.79')),
#  ('John Hancock College Preparatory High School', Decimal('0.78')),
#  ('Edward Tilden Career Community Academy High School', Decimal('0.78')),
#  ('Paul Laurence Dunbar Career Academy High School', Decimal('0.77')),
#  ('Austin Business and Entrepreneurship Academy High School', Decimal('0.76')),
#  ('New Millennium High School of Health at Bowen', Decimal('0.76')),
#  ('William J Bogan High School', Decimal('0.75')),
#  ('Percy L Julian High School', Decimal('0.75')),
#  ('Christian Fenger Academy High School', Decimal('0.74')),
#  ('Paul Robeson High School', Decimal('0.74')),
#  ('Kelvyn Park High School', Decimal('0.74')),
#  ('John Marshall Metropolitan High School', Decimal('0.74')),
#  ('Wells Community Academy High School', Decimal('0.74')),
#  ('Gage Park High School', Decimal('0.73')),
#  ('William Rainey Harper High School', Decimal('0.73')),
#  ('Hope College Preparatory High School', Decimal('0.72')),
#  ('Frederick Stock Elementary School', Decimal('0.72')),
#  ('High School of Leadership at South Shore', Decimal('0.72')),
#  ('Hyde Park Academy High School', Decimal('0.71')),
#  ('George H Corliss High School', Decimal('0.71')),
#  ('Roberto Clemente Community Academy High School', Decimal('0.70')),
#  ('Austin Polytechnical Academy High School', Decimal('0.70')),
#  ('Chicago Vocational Career Academy High School', Decimal('0.69')),
#  ('Manley Career Academy High School', Decimal('0.67')),
#  ('Orr Academy High School', Decimal('0.66')),
#  ('Wendell Phillips Academy High School', Decimal('0.63')),
#  ('Dyett High School', Decimal('0.63')),
#  ('Barbara Vick Early Childhood & Family Center', Decimal('0.61')),
#  ('Richard T Crane Technical Preparatory High School', Decimal('0.58'))]

# %% [markdown]
# ### Problem 8
#
# ##### Get the total College Enrollment for each Community Area

# %%
# %%sql
#
# select COMMUNITY_AREA_NAME, count(*) as OCCURRENCE, sum(COLLEGE_ENROLLMENT) as TOTAL_COLLEGE_ENROLLMENT
#     from CHICAGO_PUBLIC_SCHOOLS
#     group by COMMUNITY_AREA_NAME
#     order by TOTAL_COLLEGE_ENROLLMENT desc;
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 77 rows affected.
# [('SOUTH LAWNDALE', 22, Decimal('14793')),
#  ('BELMONT CRAGIN', 12, Decimal('14386')),
#  ('AUSTIN', 23, Decimal('10933')),
#  ('GAGE PARK', 10, Decimal('9915')),
#  ('BRIGHTON PARK', 8, Decimal('9647')),
#  ('WEST TOWN', 20, Decimal('9429')),
#  ('HUMBOLDT PARK', 13, Decimal('8620')),
#  ('WEST RIDGE', 9, Decimal('8197')),
#  ('NEAR WEST SIDE', 16, Decimal('7975')),
#  ('NEW CITY', 13, Decimal('7922')),
#  ('IRVING PARK', 9, Decimal('7764')),
#  ('NORTH CENTER', 7, Decimal('7541')),
#  ('LOGAN SQUARE', 11, Decimal('7351')),
#  ('LOWER WEST SIDE', 11, Decimal('7257')),
#  ('CHICAGO LAWN', 7, Decimal('7086')),
#  ('LAKE VIEW', 11, Decimal('7055')),
#  ('ROSELAND', 13, Decimal('7020')),
#  ('PORTAGE PARK', 7, Decimal('6954')),
#  ('ALBANY PARK', 8, Decimal('6864')),
#  ('ENGLEWOOD', 17, Decimal('6832')),
#  ('ASHBURN', 8, Decimal('6483')),
#  ('NORWOOD PARK', 8, Decimal('6469')),
#  ('WEST ENGLEWOOD', 13, Decimal('5946')),
#  ('LINCOLN PARK', 7, Decimal('5615')),
#  ('EAST GARFIELD PARK', 13, Decimal('5337')),
#  ('EAST SIDE', 5, Decimal('5305')),
#  ('NORTH LAWNDALE', 16, Decimal('5146')),
#  ('CHATHAM', 9, Decimal('5042')),
#  ('ARCHER HEIGHTS', 2, Decimal('4823')),
#  ('DOUGLAS', 11, Decimal('4670')),
#  ('EDGEWATER', 6, Decimal('4600')),
#  ('DUNNING', 6, Decimal('4568')),
#  ('GARFIELD RIDGE', 5, Decimal('4552')),
#  ('SOUTH SHORE', 9, Decimal('4543')),
#  ('UPTOWN', 7, Decimal('4388')),
#  ('KENWOOD', 7, Decimal('4287')),
#  ('NORTH PARK', 5, Decimal('4210')),
#  ('WEST LAWN', 4, Decimal('4207')),
#  ('WOODLAWN', 8, Decimal('4206')),
#  ('AUBURN GRESHAM', 10, Decimal('4175')),
#  ('LINCOLN SQUARE', 5, Decimal('4132')),
#  ('ROGERS PARK', 6, Decimal('4068')),
#  ('GREATER GRAND CROSSING', 10, Decimal('4051')),
#  ('SOUTH CHICAGO', 7, Decimal('4043')),
#  ('WASHINGTON HEIGHTS', 9, Decimal('4006')),
#  ('HERMOSA', 4, Decimal('3975')),
#  ('WEST ELSDON', 3, Decimal('3700')),
#  ('AVONDALE', 4, Decimal('3640')),
#  ('NEAR NORTH SIDE', 7, Decimal('3362')),
#  ('MORGAN PARK', 5, Decimal('3271')),
#  ('WEST PULLMAN', 10, Decimal('3240')),
#  ('BRIDGEPORT', 5, Decimal('3167')),
#  ('GRAND BOULEVARD', 8, Decimal('2809')),
#  ('WASHINGTON PARK', 5, Decimal('2648')),
#  ('WEST GARFIELD PARK', 8, Decimal('2622')),
#  ('MOUNT GREENWOOD', 4, Decimal('2091')),
#  ('CLEARING', 4, Decimal('2085')),
#  ('HYDE PARK', 4, Decimal('1930')),
#  ('SOUTH DEERING', 4, Decimal('1859')),
#  ('JEFFERSON PARK', 2, Decimal('1755')),
#  ('BEVERLY', 4, Decimal('1636')),
#  ('PULLMAN', 5, Decimal('1620')),
#  ('CALUMET HEIGHTS', 6, Decimal('1568')),
#  ('MCKINLEY PARK', 4, Decimal('1552')),
#  ('RIVERDALE', 4, Decimal('1547')),
#  ('AVALON PARK', 3, Decimal('1522')),
#  ('ARMOUR SQUARE', 3, Decimal('1458')),
#  ('FOREST GLEN', 3, Decimal('1431')),
#  ('NEAR SOUTH SIDE', 3, Decimal('1378')),
#  ('MONTCLARE', 1, Decimal('1317')),
#  ('HEGEWISCH', 2, Decimal('963')),
#  ('EDISON PARK', 2, Decimal('910')),
#  ('LOOP', 1, Decimal('871')),
#  ('OHARE', 1, Decimal('786')),
#  ('BURNSIDE', 1, Decimal('549')),
#  ('FULLER PARK', 2, Decimal('531')),
#  ('OAKLAND', 1, Decimal('140'))]

# %% [markdown]
# ### Problem 9
#
# ##### Get the 5 Community Areas with the least total College Enrollment  sorted in ascending order

# %%
# %%sql
#
# select COMMUNITY_AREA_NAME, count(*) as OCCURRENCE, sum(COLLEGE_ENROLLMENT) as TOTAL_COLLEGE_ENROLLMENT
#     from CHICAGO_PUBLIC_SCHOOLS
#     group by COMMUNITY_AREA_NAME
#     order by TOTAL_COLLEGE_ENROLLMENT asc
#     limit 5;
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 5 rows affected.
# [('OAKLAND', 1, Decimal('140')),
#  ('FULLER PARK', 2, Decimal('531')),
#  ('BURNSIDE', 1, Decimal('549')),
#  ('OHARE', 1, Decimal('786')),
#  ('LOOP', 1, Decimal('871'))]

# %% [markdown]
# ### Problem 10
#
# ##### Get the hardship index for the community area which has College Enrollment of 4368

# %%
# %%sql
#
# select S.COMMUNITY_AREA_NAME, S.COLLEGE_ENROLLMENT, C.HARDSHIP_INDEX
#     from CHICAGO_PUBLIC_SCHOOLS S, CHICAGO_SOCIOECONOMIC_DATA C
#     where S.COMMUNITY_AREA_NAME = C.COMMUNITY_AREA_NAME
#         and COLLEGE_ENROLLMENT = 4368
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 1 rows affected.
# [('NORTH CENTER', 4368, 6.0)]

# %% [markdown]
# ### Problem 11
#
# ##### Get the hardship index for the community area which has the highest value for College Enrollment

# %%
# %%sql
#
# select S.COMMUNITY_AREA_NAME, S.COLLEGE_ENROLLMENT, C.HARDSHIP_INDEX
#     from CHICAGO_PUBLIC_SCHOOLS S, CHICAGO_SOCIOECONOMIC_DATA C
#     where C.COMMUNITY_AREA_NAME = S.COMMUNITY_AREA_NAME
#         and COLLEGE_ENROLLMENT = (select max(COLLEGE_ENROLLMENT)
#                                   from CHICAGO_PUBLIC_SCHOOLS)
# Out:
#  * mysql://root:***@localhost/ibm_sql_lab
# 1 rows affected.
# [('NORTH CENTER', 4368, 6.0)]

# %% [markdown]
# ## Summary
#
# ##### In this lab you learned how to work with a real word dataset using SQL and Python. You learned how to query columns with spaces or special characters in their names and with mixed case names. You also used built in database functions and practiced how to sort, limit, and order result sets, as well as used sub-queries and worked with multiple tables.

# %% [markdown]
# ## Author
#
# [Temitope Adesusi](https://www.linkedin.com/in/ttadesusi)

# %% [markdown]
# ## Reference
#
# [IBM Data Science](https://www.coursera.org/professional-certificates/ibm-data-science?)
#
# [Socioeconomic Indicators in Chicago](https://github.com/ttadesusi/IBM-Data-Science-Professional-Certification/blob/master/5.%20Databases%20and%20SQL%20for%20Data%20Science/MySQL_Database-Analyzing_with_Python.ipynb)
